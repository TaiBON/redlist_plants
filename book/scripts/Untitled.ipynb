# %%
import psycopg2 as pg
import genlist_api
import re
import csv
g = genlist_api.Genlist()

# %%
g.fmtname('Tabernaemontana macrocarpa Gg', doformat=False, split=True)
# Out:
# ['Tabernaemontana macrocarpa', 'Gg']

# %%
# SQL

import sqlite3
conn = sqlite3.connect('/tmp/test2.db')

# %%
CREATE_DB = '''
CREATE TABLE redlist (
    id integer,
    family varchar,
    family_zh varchar,
    fullname varchar,
    zh_name varchar,
    category varchar
);
'''
curs = conn.cursor()
curs.execute(CREATE_DB)
conn.commit()

# %%
for r in range(len(redlistRaw)):
    INSERT = '''
    INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
    VALUES (%s, '%s', '%s', '%s', '%s', '%s');
    ''' % (redlistRaw[r][0], redlistRaw[r][3], redlistRaw[r][4],
           redlistRaw[r][5], redlistRaw[r][6], redlistRaw[r][10])
    print(INSERT)
    curs = conn.cursor()
    curs.execute(INSERT)
    conn.commit()
# Out:
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1, 'Acanthaceae', '爵床科', 'Asystasia gangetica (L.) T.Anderson', '赤道櫻草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (2, 'Acanthaceae', '爵床科', 'Asystasia gangetica (L.) T.Anderson ssp. micrantha (Nees) Ensermu', '小花寬葉馬偕花', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (3, 'Acanthaceae', '爵床科', 'Asystasiella neesiana (Nees) Lindau', '尼氏擬馬偕花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (4, 'Acanthaceae', '爵床科', 'Blechum pyramidatum (Lam.) Urb.', '賽山藍', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (5, 'Acanthaceae', '爵床科', 'Codonacanthus pauciflorus (Nees) Nees', '針刺草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (6, 'Acanthaceae', '爵床科', 'Dicliptera chinensis (L.) Juss.', '華九頭獅子草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (7, 'Acanthaceae', '爵床科', 'Dipteracanthus repens (L.) Hassk.', '蘆利草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (8, 'Acanthaceae', '爵床科', 'Hemigraphis cumingiana (Nees) Fern.-Vill.', '直立半插花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (9, 'Acanthaceae', '爵床科', 'Hemigraphis primulifolia (Ness) Fern.-Vill.', '恆春半插花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (10, 'Acanthaceae', '爵床科', 'Hemigraphis reptans (Forst.) Ander. ex Hemsl.', '匍匐半插花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (11, 'Acanthaceae', '爵床科', 'Hygrophila corymbosa (Blume) Lindau', '繖花水蓑衣', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (12, 'Acanthaceae', '爵床科', 'Hygrophila difformis (L.f.) Blume', '異葉水蓑衣', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (13, 'Acanthaceae', '爵床科', 'Hygrophila guianensis Nees ', '蓋亞那水蓑衣', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (14, 'Acanthaceae', '爵床科', 'Hygrophila lancea (Thunb.) Miq.', '水蓑衣', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (15, 'Acanthaceae', '爵床科', 'Hygrophila pogonocalyx Hayata ', '大安水蓑衣', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (16, 'Acanthaceae', '爵床科', 'Hygrophila polysperma T.Anderson', '小獅子草', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (17, 'Acanthaceae', '爵床科', 'Hygrophila salicifolia (Vahl) Nees', '柳葉水蓑衣', 'NT*');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (18, 'Acanthaceae', '爵床科', 'Hygrophila stricta (Nees) Lindau', '刻脈水蓑衣', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (19, 'Acanthaceae', '爵床科', 'Hypoestes cumingiana Benth. & Hook.', '槍刀菜', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (20, 'Acanthaceae', '爵床科', 'Hypoestes purpurea R.Br.', '六角英', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (21, 'Acanthaceae', '爵床科', 'Justicia comata (L.) Lam.', '穗花爵床', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (22, 'Acanthaceae', '爵床科', 'Justicia gendarussa Brum.f.', '尖尾鳳', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (23, 'Acanthaceae', '爵床科', 'Justicia procumbens L. var. hayatae (Yamam.) Ohwi', '早田氏爵床', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (24, 'Acanthaceae', '爵床科', 'Justicia procumbens L. var. hirsuta Yamam.', '密毛爵床', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (25, 'Acanthaceae', '爵床科', 'Justicia procumbens L. var. linearifolia Yamam.', '狹葉爵床', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (26, 'Acanthaceae', '爵床科', 'Justicia procumbens L. var. procumbens', '爵床', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (27, 'Acanthaceae', '爵床科', 'Justicia quadrifaria (Nees) T.Anderson', '花蓮爵床', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (28, 'Acanthaceae', '爵床科', 'Kudoacanthus albonervosa Hosok.', '銀脈爵床', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (29, 'Acanthaceae', '爵床科', 'Lepidagathis formosensis C.B.Clarke ex Hayata', '臺灣鱗球花', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (30, 'Acanthaceae', '爵床科', 'Lepidagathis inaequalis C.B.Clarke ex Elmer', '卵葉鱗球花', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (31, 'Acanthaceae', '爵床科', 'Lepidagathis secunda (Blanco) Nees', '小琉球鱗球花', 'EN*');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (32, 'Acanthaceae', '爵床科', 'Lepidagathis stenophylla C.B.Clarke ex Hayata', '柳葉鱗球花', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (33, 'Acanthaceae', '爵床科', 'Nelsonia canescens (Lam.) Spreng.', '瘤子草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (34, 'Acanthaceae', '爵床科', 'Peristrophe japonica (Thunb.) Bremek.', '九頭獅子草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (35, 'Acanthaceae', '爵床科', 'Peristrophe roxburghiana (Schult.) Bremek.', '長花九頭獅子草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (36, 'Acanthaceae', '爵床科', 'Ruellia brittoniana Leonard', '紫花蘆利草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (37, 'Acanthaceae', '爵床科', 'Ruellia squarrosa (Fenzl) Schaffnit', '蔓枝蘆莉草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (38, 'Acanthaceae', '爵床科', 'Ruellia tuberosa L.', '塊根蘆利草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (39, 'Acanthaceae', '爵床科', 'Rungia chinensis Benth.', '明萼草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (40, 'Acanthaceae', '爵床科', 'Rungia taiwanensis T.Yamaz.', '臺灣明萼草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (41, 'Acanthaceae', '爵床科', 'Staurogyne concinnula (Hance) Kuntze', '哈哼花', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (42, 'Acanthaceae', '爵床科', 'Staurogyne debilis (T.Anderson) C.B.Clarke ex Mill.', '菲律賓哈哼花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (43, 'Acanthaceae', '爵床科', 'Strobilanthes cusia (Ness) Kuntze', '馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (44, 'Acanthaceae', '爵床科', 'Strobilanthes flexicaulis Hayata', '曲莖馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (45, 'Acanthaceae', '爵床科', 'Strobilanthes formosana S.Moore', '臺灣馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (46, 'Acanthaceae', '爵床科', 'Strobilanthes lanyuensis Seok, C.F.Hsieh & J.Murata', '蘭嶼馬蘭', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (47, 'Acanthaceae', '爵床科', 'Strobilanthes longespicatus Hayata', '長穗馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (48, 'Acanthaceae', '爵床科', 'Strobilanthes penstemonoides T.Anderson', '腺萼馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (49, 'Acanthaceae', '爵床科', 'Strobilanthes rankanensis Hayata', '蘭崁馬藍', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (50, 'Acanthaceae', '爵床科', 'Strobilanthes wallichii Nees ', '翅柄馬蘭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (51, 'Acanthaceae', '爵床科', 'Thunbergia alata Bojer ex Sims', '黑眼花', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (52, 'Acanthaceae', '爵床科', 'Thunbergia fragrans Roxb. ', '碗花草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (53, 'Acanthaceae', '爵床科', 'Thunbergia grandiflora Roxb.', '大鄧伯花', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (54, 'Sapindaceae', '無患子科', 'Acer albopurpurascens Hayata', '樟葉槭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (55, 'Sapindaceae', '無患子科', 'Acer buergerianum Miq. var. formosanum (Hayata) Sasaki', '臺灣三角楓', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (56, 'Sapindaceae', '無患子科', 'Acer kawakamii Koidz.', '尖葉槭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (57, 'Sapindaceae', '無患子科', 'Acer morrisonense Hayata', '臺灣紅榨槭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (58, 'Sapindaceae', '無患子科', 'Acer palmatum Thunb. var. pubescens H.L.Li', '臺灣掌葉槭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (59, 'Sapindaceae', '無患子科', 'Acer serrulatum Hayata', '青楓', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (60, 'Actinidiaceae', '獼猴桃科', 'Actinidia arguta (Sieb. & Zucc.) Planch. ex Miq.', '軟棗獼猴桃', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (61, 'Actinidiaceae', '獼猴桃科', 'Actinidia callosa Lindl.', '硬齒獼猴桃', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (62, 'Actinidiaceae', '獼猴桃科', 'Actinidia callosa Lindl. var. discolor C.F.Liang', '異色獼猴桃', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (63, 'Actinidiaceae', '獼猴桃科', 'Actinidia callosa Lindl. var. ephippioidea C.F.Liang', '駝齒獼猴桃', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (64, 'Actinidiaceae', '獼猴桃科', 'Actinidia chinensis Planch. var. setosa H.L.Li', '臺灣羊桃', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (65, 'Actinidiaceae', '獼猴桃科', 'Actinidia latifolia (Gardn. & Champ.) Merr.', '闊葉獼猴桃', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (66, 'Actinidiaceae', '獼猴桃科', 'Actinidia rubricaulis Dunn', '紅莖獼猴桃', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (67, 'Actinidiaceae', '獼猴桃科', 'Actinidia rufa (Siebold & Zucc.) Planch. ex Miq.', '腺齒獼猴桃', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (68, 'Actinidiaceae', '獼猴桃科', 'Saurauia tristyla DC. var. oldhamii (Hemsl.) Finet & Gagnep.', '水冬瓜', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (69, 'Pteridaceae', '鳳尾蕨科', 'Acrostichum aureum L.', '鹵蕨', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (70, 'Pteridaceae', '鳳尾蕨科', 'Adiantum capillus-junonis Rupr. ', '團羽鐵線蕨 ', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (71, 'Pteridaceae', '鳳尾蕨科', 'Adiantum capillus-veneris L.', '鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (72, 'Pteridaceae', '鳳尾蕨科', 'Adiantum capillus-veneris L. f. lanyuanum W.C.Shieh ', '蘭嶼鐵線蕨', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (73, 'Pteridaceae', '鳳尾蕨科', 'Adiantum caudatum L.', '鞭葉鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (74, 'Pteridaceae', '鳳尾蕨科', 'Adiantum ciliatum Blume', '馬來鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (75, 'Pteridaceae', '鳳尾蕨科', 'Adiantum diaphanum Blume', '長尾鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (76, 'Pteridaceae', '鳳尾蕨科', 'Adiantum edgeworthii Hook.', '愛氏鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (77, 'Pteridaceae', '鳳尾蕨科', 'Adiantum flabellulatum L.', '扇葉鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (78, 'Pteridaceae', '鳳尾蕨科', 'Adiantum formosanum Tagawa', '深山鐵線蕨', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (79, 'Pteridaceae', '鳳尾蕨科', 'Adiantum hispidulum Sw.', '毛葉鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (80, 'Pteridaceae', '鳳尾蕨科', 'Adiantum meishanianum F.S.Hsu ex Yea C.Liu & W.L.Chiou#', '梅山口鐵線蕨', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (81, 'Pteridaceae', '鳳尾蕨科', 'Adiantum menglianense Y.Y.Qian', '孟連鐵線蕨', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (82, 'Pteridaceae', '鳳尾蕨科', 'Adiantum monochlamys Eaton', '石長生', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (83, 'Pteridaceae', '鳳尾蕨科', 'Adiantum myriosorum Baker', '灰背鐵線蕨', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (84, 'Pteridaceae', '鳳尾蕨科', 'Adiantum philippense L.', '半月鐵線蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (85, 'Pteridaceae', '鳳尾蕨科', 'Adiantum roborowskii Maxim. var. taiwanianum (Tagawa) W.C.Shieh ', '臺灣高山鐵線蕨', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (86, 'Pteridaceae', '鳳尾蕨科', 'Adiantum soboliferum Wall. ex Hook.', '翅柄鐵線蕨', 'VU ');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (87, 'Pteridaceae', '鳳尾蕨科', 'Anogramma leptophylla (L.) Link', '翠蕨', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (88, 'Pteridaceae', '鳳尾蕨科', 'Coniogramme fraxinea (D.Don) Diels', '全緣鳳丫蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (89, 'Pteridaceae', '鳳尾蕨科', 'Coniogramme intermedia Heiron.', '華鳳丫蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (90, 'Pteridaceae', '鳳尾蕨科', 'Coniogramme japonica (Thunb.) Diels', '日本鳳丫蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (91, 'Pteridaceae', '鳳尾蕨科', 'Coniogramme procera Fée', '高山鳳丫蕨', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (92, 'Pteridaceae', '鳳尾蕨科', 'Paragymnopteris vestita (Wall. ex C.Presl) K.H.Shing', '金毛裸蕨', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (93, 'Pteridaceae', '鳳尾蕨科', 'Parahemionitis arifolia (Burm.f.) Panigrahi', '澤瀉蕨', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (94, 'Pteridaceae', '鳳尾蕨科', 'Pityrogramma calomelanos (L.) Link', '粉葉蕨', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (95, 'Asparagaceae', '天門冬科', 'Agave americana L.', '龍舌蘭', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (96, 'Asparagaceae', '天門冬科', 'Agave fourcroydes Lem.', '黃條龍舌蘭', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (97, 'Asparagaceae', '天門冬科', 'Agave gigantean L.', '大龍舌蘭', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (98, 'Asparagaceae', '天門冬科', 'Agave sisalana Perr. ex Enghlm.', '瓊麻', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (99, 'Asparagaceae', '天門冬科', 'Dracaena angustifolia Roxb.', '番仔林投', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (100, 'Aizoaceae', '番杏科', 'Sesuvium portulacastrum (L.) L.', '海馬齒', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (101, 'Aizoaceae', '番杏科', 'Tetragonia tetragonoides (Pall.) Kuntze', '番杏', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (102, 'Aizoaceae', '番杏科', 'Trianthema portulacastrum L.', '假海馬齒', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (103, 'Cornaceae', '山茱萸科', 'Alangium chinense (Lour.) Rehder', '華八角楓', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (104, 'Alismataceae', '澤瀉科', 'Alisma canaliculatum A.Braun & Bouché ', '澤瀉', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (105, 'Alismataceae', '澤瀉科', 'Caldesia grandis Samuel.', '圓葉澤瀉', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (106, 'Alismataceae', '澤瀉科', 'Echinodorus cordifolius (L.) Griseb.', '心葉齒果澤瀉', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (107, 'Alismataceae', '澤瀉科', 'Sagittaria guayanensis Kunth subsp. lappula (D. Don) Bogin', '臺灣冠果草', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (108, 'Alismataceae', '澤瀉科', 'Sagittaria pygmea Miq.', '瓜皮草(線慈菇)', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (109, 'Alismataceae', '澤瀉科', 'Sagittaria trifolia L. ', '三腳剪', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (110, 'Amaranthaceae', '莧科', 'Achyranthes aspera L. var. indica L.', '印度牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (111, 'Amaranthaceae', '莧科', 'Achyranthes aspera L. var. rubro-fusca Hook. f.', '紫莖牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (112, 'Amaranthaceae', '莧科', 'Achyranthes bidentata Blume', '牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (113, 'Amaranthaceae', '莧科', 'Achyranthes bidentata Blume var. japonica Miq.', '日本牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (114, 'Amaranthaceae', '莧科', 'Achyranthes longifolia (Makino) Makino', '柳葉牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (115, 'Amaranthaceae', '莧科', 'Aerva sanguinolenta Blume', '絹毛莧(蔓雞冠)', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (116, 'Amaranthaceae', '莧科', 'Alternanthera bettzickiana (Regel) Nicholson', '毛蓮子草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (117, 'Amaranthaceae', '莧科', 'Alternanthera paronychioides St. Hil.', '匙葉蓮子草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (118, 'Amaranthaceae', '莧科', 'Alternanthera philoxeroides (Mart.) Griseb.', '空心蓮子草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (119, 'Amaranthaceae', '莧科', 'Alternanthera reineckii Briquet', '瑞氏蓮子草', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (120, 'Amaranthaceae', '莧科', 'Alternanthera sessilis (L.) R.Br.', '蓮子草', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (121, 'Amaranthaceae', '莧科', 'Amaranthus caudatus L.', '尾穗莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (122, 'Amaranthaceae', '莧科', 'Amaranthus dubius Mart. ex Thell.', '假刺莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (123, 'Amaranthaceae', '莧科', 'Amaranthus hybridus L.', '綠穂莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (124, 'Amaranthaceae', '莧科', 'Amaranthus lividus L.', '凹葉野莧菜', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (125, 'Amaranthaceae', '莧科', 'Amaranthus patulus Bertol.', '青莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (126, 'Amaranthaceae', '莧科', 'Amaranthus retroflexus L.', '反刺莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (127, 'Amaranthaceae', '莧科', 'Amaranthus spinosus L.', '刺莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (128, 'Amaranthaceae', '莧科', 'Amaranthus viridis L.', '野莧菜', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (129, 'Amaranthaceae', '莧科', 'Celosia argentea L.', '青葙', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (130, 'Amaranthaceae', '莧科', 'Celosia taitoensis Hayata ', '臺東青葙', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (131, 'Amaranthaceae', '莧科', 'Cyathula prostrata (L.) Blume', '假川牛膝', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (132, 'Amaranthaceae', '莧科', 'Deeringia amaranthoides (Lam.) Merr.', '漿果莧', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (133, 'Amaranthaceae', '莧科', 'Deeringia polysperma (Roxb.) Miq.', '多子漿果莧', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (134, 'Amaranthaceae', '莧科', 'Digera muricata (L.) Mart.', '瘤果莧', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (135, 'Amaranthaceae', '莧科', 'Gomphrena celosioides Mart.', '假千日紅', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (136, 'Amaranthaceae', '莧科', 'Gomphrena serrata L.', '短穗假千日紅', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (137, 'Amaranthaceae', '莧科', 'Philoxerus wrightii Hook.f.', '安旱草', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (138, 'Amaranthaceae', '莧科', 'Pupalia micrantha Hauman', '小花鉤牛膝', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (139, 'Amaryllidaceae', '石蒜科', 'Crinum asiaticum L.', '文珠蘭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (140, 'Amaryllidaceae', '石蒜科', 'Lycoris aurea Herb.', '龍爪花', 'EN ');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (141, 'Taxaceae', '紅豆杉科', 'Amentotaxus formosana H.L.Li', '臺灣穗花杉', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (142, 'Anacardiaceae', '漆樹科', 'Buchanania arborescens Blume', '山羨子', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (143, 'Anacardiaceae', '漆樹科', 'Mangifera indica Linn.', '檬果', '');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (144, 'Anacardiaceae', '漆樹科', 'Pistacia chinensis Bunge', '黃連木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (145, 'Anacardiaceae', '漆樹科', 'Rhus ambigua Lav. ex Dippel', '臺灣藤漆', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (146, 'Anacardiaceae', '漆樹科', 'Rhus hypoleuca Champ. ex Benth.', '裏白漆', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (147, 'Anacardiaceae', '漆樹科', 'Rhus javanica L. var. roxburghiana (DC.) Rehder & E. H. Wils.', '羅氏鹽膚木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (148, 'Anacardiaceae', '漆樹科', 'Rhus succedanea L.', '木蠟樹', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (149, 'Anacardiaceae', '漆樹科', 'Rhus succedanea L. var. dumoutieri Kudo et Matsura ', '安南漆', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (150, 'Anacardiaceae', '漆樹科', 'Rhus sylvestris Siebold & Zucc.', '野漆樹', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (151, 'Anacardiaceae', '漆樹科', 'Schinus terebinthifolius Raddi', '巴西胡椒木', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (152, 'Anacardiaceae', '漆樹科', 'Semecarpus cuneiformis Blanco', '鈍葉大果漆', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (153, 'Anacardiaceae', '漆樹科', 'Semecarpus gigantifolia Vidal', '臺東漆樹', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (154, 'Annonaceae', '番荔枝科', 'Fissistigma glaucescens (Hance) Merr.', '裏白瓜馥木', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (155, 'Annonaceae', '番荔枝科', 'Fissistigma oldhamii (Hemsl.) Merr.', '瓜馥木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (156, 'Annonaceae', '番荔枝科', 'Goniothalamus amuyon (Blanco) Merr.', '恆春哥納香', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (157, 'Annonaceae', '番荔枝科', 'Polyalthia liukiuensis Hatus.', '琉球暗羅', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (158, 'Apocynaceae', '夾竹桃科', 'Alstonia scholaris (L.) R.Br.', '黑板樹', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (159, 'Apocynaceae', '夾竹桃科', 'Alyxia sibuyanensis Elmer', '蘭嶼念珠藤', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (160, 'Apocynaceae', '夾竹桃科', 'Alyxia sinensis Champ. ex Benth.', '中國念珠藤', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (161, 'Apocynaceae', '夾竹桃科', 'Alyxia taiwanensis S.Y.Lu & Yuen P.Yang', '臺灣念珠藤', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (162, 'Apocynaceae', '夾竹桃科', 'Anodendron affine (Hook. & Arn.) Druce', '小錦蘭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (163, 'Apocynaceae', '夾竹桃科', 'Anodendron benthamiana Hemsl.', '大錦蘭', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (164, 'Apocynaceae', '夾竹桃科', 'Catharanthus roseus (L.) G.Don', '長春花', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (165, 'Apocynaceae', '夾竹桃科', 'Cerbera manghas L.', '海檬果', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (166, 'Apocynaceae', '夾竹桃科', 'Ecdysanthera rosea Hook. & Arn.', '酸藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (167, 'Apocynaceae', '夾竹桃科', 'Ecdysanthera utilis Hayata & Kawak.', '乳藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (168, 'Apocynaceae', '夾竹桃科', 'Holarrhena pubescens Wall. ex G.Don', '止瀉木', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (169, 'Apocynaceae', '夾竹桃科', 'Melodinus angustifolius Hayata', '山橙', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (170, 'Apocynaceae', '夾竹桃科', 'Parsonia laevigata (Moon) Alston', '爬森藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (171, 'Apocynaceae', '夾竹桃科', 'Rauvolfia tetraphylla L.', '四葉蘿芙木', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (172, 'Apocynaceae', '夾竹桃科', 'Rauvolfia verticillata (Lour.) Baill.', '蘿芙木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (173, 'Apocynaceae', '夾竹桃科', 'Tabernaemontana pandacaqui Poir.', '南洋馬蹄花', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (174, 'Apocynaceae', '夾竹桃科', 'Tabernaemontana subglobosa Merr.', '蘭嶼馬蹄花', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (175, 'Apocynaceae', '夾竹桃科', 'Trachelospermum formosanum Y. C. Liu & C. H. Ou', '臺灣絡石', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (176, 'Apocynaceae', '夾竹桃科', 'Trachelospermum gracilipes Hook. f.', '細梗絡石', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (177, 'Apocynaceae', '夾竹桃科', 'Trachelospermum jasminoides (Lindl.) Lemaire', '絡石', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (178, 'Apocynaceae', '夾竹桃科', 'Trachelospermum lanyuense C. E. Chang', '蘭嶼絡石', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (179, 'Aponogetonaceae', '水蕹科', 'Aponogeton taiwanensis Masam.', '水蕹', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (180, 'Aquifoliaceae', '冬青科', 'Ilex arisanensis Yamam.', '阿里山冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (181, 'Aquifoliaceae', '冬青科', 'Ilex asprella (Hook. & Arn.) Champ.', '燈稱花', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (182, 'Aquifoliaceae', '冬青科', 'Ilex bioritsensis Hayata', '苗栗冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (183, 'Aquifoliaceae', '冬青科', 'Ilex cochinchinensis (Lour.) Loes.', '革葉冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (184, 'Aquifoliaceae', '冬青科', 'Ilex crenata Thunb.', '假黃楊', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (185, 'Aquifoliaceae', '冬青科', 'Ilex ficoidea Hemsl.', '臺灣糊樗', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (186, 'Aquifoliaceae', '冬青科', 'Ilex formosana Maxim.', '糊樗', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (187, 'Aquifoliaceae', '冬青科', 'Ilex goshiensis Hayata', '圓葉冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (188, 'Aquifoliaceae', '冬青科', 'Ilex hayataiana Loes.', '早田氏冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (189, 'Aquifoliaceae', '冬青科', 'Ilex integra Thunb.', '全緣葉冬青', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (190, 'Aquifoliaceae', '冬青科', 'Ilex kusanoi Hayata', '草野氏冬青', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (191, 'Aquifoliaceae', '冬青科', 'Ilex lonicerifolia Hayata', '忍冬葉冬青', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (192, 'Aquifoliaceae', '冬青科', 'Ilex lonicerifolia Hayata var. matsudai Yamam.', '松田氏冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (193, 'Aquifoliaceae', '冬青科', 'Ilex maximowicziana Loes.', '倒卵葉冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (194, 'Aquifoliaceae', '冬青科', 'Ilex micrococca Maxim.', '朱紅水木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (195, 'Aquifoliaceae', '冬青科', 'Ilex pedunculosa Miq.', '刻脈冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (196, 'Aquifoliaceae', '冬青科', 'Ilex pubescens Hook. & Arn.', '密毛假黃楊', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (197, 'Aquifoliaceae', '冬青科', 'Ilex rarasanensis Sasaki', '拉拉山冬青', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (198, 'Aquifoliaceae', '冬青科', 'Ilex rotunda Thunb.', '鐵冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (199, 'Aquifoliaceae', '冬青科', 'Ilex sugerokii Maxim. var. brevipedunculata (Maxim.) S. Y. Hu', '太平山冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (200, 'Aquifoliaceae', '冬青科', 'Ilex suzukii S.Y.Hu', '鈴木氏冬青', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (201, 'Aquifoliaceae', '冬青科', 'Ilex taiwanensis Hayata', '長梗花冬青', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (202, 'Aquifoliaceae', '冬青科', 'Ilex tugitakayamensis Sasaki', '雪山冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (203, 'Aquifoliaceae', '冬青科', 'Ilex uraiensis Mori & Yamam.', '烏來冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (204, 'Aquifoliaceae', '冬青科', 'Ilex yunnanensis Frranch. var. parvifolia (Hayata) S.Y.Hu', '雲南冬青', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (205, 'Acoraceae', '菖蒲科', 'Acorus gramineus Soland.', '石菖蒲', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (206, 'Acoraceae', '菖蒲科', 'Acorus gramineus Soland. var. macrospadiceus Yamam.', '大穗石菖蒲', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (207, 'Araceae', '天南星科', 'Alocasia cucullata (Lour.) Schott', '臺灣姑婆芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (208, 'Araceae', '天南星科', 'Alocasia macrorrhizos (L) G.Don', '海芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (209, 'Araceae', '天南星科', 'Alocasia odora (Lodd.) Spach.', '姑婆芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (210, 'Araceae', '天南星科', 'Amorphophallus henryi N.E.Br.', '臺灣魔芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (211, 'Araceae', '天南星科', 'Amorphophallus hirtus N.E.Br', '密毛魔芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (212, 'Araceae', '天南星科', 'Amorphophallus kiusianus (Makino) Makino', '東亞魔芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (213, 'Araceae', '天南星科', 'Amorphophallus paeoniifolius (Dennst.) Nicolson', '疣柄魔芋', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (214, 'Araceae', '天南星科', 'Arisaema consanguineum Schott', '長行天南星', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (215, 'Araceae', '天南星科', 'Arisaema formosanum (Hayata) Hayata', '臺灣天南星', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (216, 'Araceae', '天南星科', 'Arisaema grapsospadix Hayata', '毛筆天南星', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (217, 'Araceae', '天南星科', 'Arisaema heterophyllum Blume', '羽葉天南星', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (218, 'Araceae', '天南星科', 'Arisaema ilanense J.C.Wang', '宜蘭天南星', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (219, 'Araceae', '天南星科', 'Arisaema matsudae Hayata', '線花天南星', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (220, 'Araceae', '天南星科', 'Arisaema nanjenense T.C.Huang ＆ M.J.Wu', '南仁山天南星', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (221, 'Araceae', '天南星科', 'Arisaema ringens (Thunb.) Schott', '申跋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (222, 'Araceae', '天南星科', 'Arisaema taiwanense J.Murata', '蓬萊天南星', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (223, 'Araceae', '天南星科', 'Arisaema taiwanense J.Murata var. brevipedunculatum J.Murata', '短梗天南星', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (224, 'Araceae', '天南星科', 'Arisaema thunbergii Blume subsp. autumnale J.C.Wang, J.Murata ＆ H.Ohashi', '東臺天南星', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (225, 'Araceae', '天南星科', 'Colocasia esculenta (L.) Schott', '芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (226, 'Araceae', '天南星科', 'Colocasia esculenta (L.) Schott var. antiquorum (Schott) Hubb. & Rehder', '檳榔芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (227, 'Araceae', '天南星科', 'Colocasia formosana Hayata', '臺灣青芋', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (228, 'Araceae', '天南星科', 'Colocasia gigantea (Blume) Hook.f.', '大野芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (229, 'Araceae', '天南星科', 'Colocasia tonoimo Nakai', '紫芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (230, 'Araceae', '天南星科', 'Epipremnum aureum (Linden & André) G.S.Bunting', '黃金葛', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (231, 'Araceae', '天南星科', 'Epipremnum formosanum Hayata', '臺灣拎樹藤', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (232, 'Araceae', '天南星科', 'Epipremnum pinnatum (L.) Engl. ex Engl. & Kraus', '拎樹藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (233, 'Araceae', '天南星科', 'Homalomena kelungensis Hayata', '基隆扁葉芋', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (234, 'Araceae', '天南星科', 'Homalomena philippinensis Engl. ex Engl. & Kraus', '菲律賓扁葉芋', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (235, 'Araceae', '天南星科', 'Pinellia ternata (Thunb.) Breit.', '半夏', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (236, 'Araceae', '天南星科', 'Pistia stratiotes L.', '大萍', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (237, 'Araceae', '天南星科', 'Pothoidium lobbianum Schott', '假柚葉藤', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (238, 'Araceae', '天南星科', 'Pothos chinensis (Raf.) Merr.', '柚葉藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (239, 'Araceae', '天南星科', 'Remusatia vivipara (Lodd.) Schott', '臺灣目賊芋', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (240, 'Araceae', '天南星科', 'Remusatia yunnanensis (H.Li & A.Hay) A.Hay ', '雲南岩芋', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (241, 'Araceae', '天南星科', 'Rhaphidophora hongkongensis Schott', '香港針房藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (242, 'Araceae', '天南星科', 'Rhaphidophora liukiuensis Hatus.', '針房藤', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (243, 'Araceae', '天南星科', 'Schismatoglottis kotoensis (Hayata) T.C.Huang, J.L.Hsiao & H.Y.Yeh', '蘭嶼芋', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (244, 'Araceae', '天南星科', 'Syngonium podophyllum Schott', '合果芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (245, 'Araceae', '天南星科', 'Typhonium blumei Nicolson & Sivadasan', '土半夏', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (246, 'Araceae', '天南星科', 'Typhonium roxburghii Schott', '金慈姑', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (247, 'Araceae', '天南星科', 'Xanthosoma sagittifolium (L.) Schott', '千年芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (248, 'Araceae', '天南星科', 'Xanthosoma violaceum Schott', '紫柄千年芋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (249, 'Araliaceae', '五加科', 'Aralia armata (Wall.) Seem.', '虎刺楤木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (250, 'Araliaceae', '五加科', 'Aralia bipinnata Blanco', '裡白楤木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (251, 'Araliaceae', '五加科', 'Aralia cordata Thunb.', '食用土當歸', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (252, 'Araliaceae', '五加科', 'Aralia decaisneana Hance', '鵲不踏', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (253, 'Araliaceae', '五加科', 'Dendropanax dentiger (Harms ex Diels) Merr.', '臺灣樹參', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (254, 'Araliaceae', '五加科', 'Dendropanax trifidus (Thumb.) Makino', '三菱果樹參', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (255, 'Araliaceae', '五加科', 'Eleutherococcus trifoliatus (L.) S.Y.Hu', '三葉五加', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (256, 'Araliaceae', '五加科', 'Eleutherococcus trifoliatus (L.) S.Y.Hu var. setosus (H.L.Li) H.Ohashi', '毛脈三葉五加', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (257, 'Araliaceae', '五加科', 'Fatsia polycarpa Hayata', '臺灣八角金盤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (258, 'Araliaceae', '五加科', 'Hedera rhombea (Miq.) Bean var. formosana (Nakai)) H.L.Li', '臺灣常春藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (259, 'Araliaceae', '五加科', 'Osmoxylon pectinatum (Merr.) Philipson', '蘭嶼八角金盤', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (260, 'Araliaceae', '五加科', 'Pentapanax castanopsisicola Hayata', '臺灣五葉參', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (261, 'Araliaceae', '五加科', 'Schefflera arboricola (Hayata) Kaneh.', '鵝掌蘗', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (262, 'Araliaceae', '五加科', 'Schefflera octophylla (Lour.) Harms', '鵝掌柴', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (263, 'Araliaceae', '五加科', 'Schefflera odorata (Blanco) Merr. & Rolfe', '鵝掌藤', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (264, 'Araliaceae', '五加科', 'Schefflera taiwaniana (Nakai) Kanehira', '臺灣鵝掌柴', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (265, 'Araliaceae', '五加科', 'Sinopanax formosana (Hayata) H.L.Li', '華參', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (266, 'Araliaceae', '五加科', 'Tetrapanax papyriferus (Hook.) K.Koch', '通脫木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (267, 'Aristolochiaceae', '馬兜鈴科', 'Aristolochia cucurbitifolia Hayata', '瓜葉馬兜鈴', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (268, 'Aristolochiaceae', '馬兜鈴科', 'Aristolochia foveolata Merr.', '蜂窩馬兜鈴', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (269, 'Aristolochiaceae', '馬兜鈴科', 'Aristolochia heterophylla Hemsl.', '異葉馬兜鈴', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (270, 'Aristolochiaceae', '馬兜鈴科', 'Aristolochia yujungiana C.T.Lu & J.C.Wang', '裕榮馬兜鈴', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (271, 'Aristolochiaceae', '馬兜鈴科', 'Aristolochia zollingeriana Miq.', '港口馬兜鈴', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (272, 'Aristolochiaceae', '馬兜鈴科', 'Asarum caudigerum Hance', '薄葉細辛', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (273, 'Aristolochiaceae', '馬兜鈴科', 'Asarum chatienshanianum C.T.Lu & J.C.Wang', '插天山細辛', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (274, 'Aristolochiaceae', '馬兜鈴科', 'Asarum crassusepalum S.F.Huang', '鴛鴦湖細辛', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (275, 'Aristolochiaceae', '馬兜鈴科', 'Asarum epigynum Hayata', '上花細辛', 'VU');
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (276, 'Aristolochiaceae', '馬兜鈴科', 'Asarum hypogynum Hayata', '下花細辛', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (277, 'Aristolochiaceae', '馬兜鈴科', 'Asarum macranthum Hook.f.', '大花細辛', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (278, 'Aristolochiaceae', '馬兜鈴科', 'Asarum satsumense F.Maek.', '薩摩細辛', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (279, 'Aristolochiaceae', '馬兜鈴科', 'Asarum taipingshanianum S.F.Huang', '太平山細辛', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (280, 'Aristolochiaceae', '馬兜鈴科', 'Asarum tawushanianum C.T.Lu & J.C.Wang', '大武山細辛', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (281, 'Aristolochiaceae', '馬兜鈴科', 'Asarum villisepalum C.T.Lu & J.C.Wang', '神秘湖細辛', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (282, 'Aristolochiaceae', '馬兜鈴科', 'Asarum yaeyamense Hatusima', '八重山細辛', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (283, 'Apocynaceae', '夾竹桃科', 'Asclepias curassavica L.', '馬利筋', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
# ...
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1778, 'Fagaceae', '殼斗科', 'Castanopsis cuspidata (Thunb.) Schottky var. carlesii (Hemsl.) Yamaz.', '長尾尖葉櫧', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1779, 'Fagaceae', '殼斗科', 'Castanopsis cuspidata (Thunb.) Schottky var. carlesii (Hemsl.) Yamaz. f. sessilis (Nakai) Liao', '白校欑', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1780, 'Fagaceae', '殼斗科', 'Castanopsis eyrei (Champ. ex Benth.) Hutch.', '反刺苦櫧', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1781, 'Fagaceae', '殼斗科', 'Castanopsis fabri Hance', '星刺栲', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1782, 'Fagaceae', '殼斗科', 'Castanopsis fargesii Franch.', '火燒柯', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1783, 'Fagaceae', '殼斗科', 'Castanopsis formosana (Skan) Hayata ', '臺灣苦櫧', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1784, 'Fagaceae', '殼斗科', 'Castanopsis indica (Rox.) A. DC. ', '印度苦櫧', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1785, 'Fagaceae', '殼斗科', 'Castanopsis kawakamii Hayata', '大葉苦櫧', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1786, 'Fagaceae', '殼斗科', 'Castanopsis kusanoi Hayata', '細刺苦櫧', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1787, 'Fagaceae', '殼斗科', 'Castanopsis uraiana (Hayata) Kaneh. & Hatus.', '烏來柯', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1788, 'Fagaceae', '殼斗科', 'Fagus hayatae Palib. ex Hayata', '臺灣水青岡', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1789, 'Fagaceae', '殼斗科', 'Lithocarpus amygdalifolius (Skan ex Forbes & Hemsl.) Hayata', '杏葉石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1790, 'Fagaceae', '殼斗科', 'Lithocarpus chiaratuangensis (J.C.Liao) J.C.Liao ', '加拉段柯', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1791, 'Fagaceae', '殼斗科', 'Lithocarpus corneus (Lour.) Rehder', '後大埔石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1792, 'Fagaceae', '殼斗科', 'Lithocarpus dodonaeifolius (Hayata) Hayata', '柳葉石櫟', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1793, 'Fagaceae', '殼斗科', 'Lithocarpus formosanus (Skan ex Forbes & Hemsl.) Hayata', '臺灣石櫟', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1794, 'Fagaceae', '殼斗科', 'Lithocarpus glaber (Thunb.) Nakai', '子彈石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1795, 'Fagaceae', '殼斗科', 'Lithocarpus harlandii (Hance ex Walp.) Rehder', '短尾葉石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1796, 'Fagaceae', '殼斗科', 'Lithocarpus kawakamii (Hayata) Hayata', '大葉石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1797, 'Fagaceae', '殼斗科', 'Lithocarpus konishii (Hayata) Hayata', '油葉石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1798, 'Fagaceae', '殼斗科', 'Lithocarpus lepidocarpus ( Hayata ) Hayata', '鬼石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1799, 'Fagaceae', '殼斗科', 'Lithocarpus nantoensis (Hayata) Hayata', '南投石櫟', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1800, 'Fagaceae', '殼斗科', 'Lithocarpus shinsuiensis Hayata & Kaneh.', '浸水營石櫟', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1801, 'Fagaceae', '殼斗科', 'Lithocarpus synbalanos (Hance) Chun', '菱果石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1802, 'Fagaceae', '殼斗科', 'Lithocarpus taitoensis (Hayata) Hayata', '臺東石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1803, 'Fagaceae', '殼斗科', 'Pasania hancei (Benth.) Schottky var. arisanensis (Hayata) J. C. Liao', '阿里山三斗石櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1804, 'Fagaceae', '殼斗科', 'Pasania hancei (Benth.) Schottky var. ternaticupula (Hayata) J. C. Liao', '三斗石櫟', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1805, 'Fagaceae', '殼斗科', 'Pasania hancei (Benth.) Schottky var. ternaticupula (Hayata) Liao f. subreticulata (Hayata) J.
# C. Liao', '細葉三斗石櫟', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1806, 'Fagaceae', '殼斗科', 'Quercus acutissima Carruth.', '麻櫟', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1807, 'Fagaceae', '殼斗科', 'Quercus aliena Blume', '大槲樹', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1808, 'Fagaceae', '殼斗科', 'Quercus championii Benth. ', '嶺南青剛櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1809, 'Fagaceae', '殼斗科', 'Quercus dentata Thunb.', '槲樹', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1810, 'Fagaceae', '殼斗科', 'Quercus gilva Blume ', '赤皮', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1811, 'Fagaceae', '殼斗科', 'Quercus glandulifera Blume var. brevipetiolata (A. DC.) Nakai ', '思茅櫧櫟', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1812, 'Fagaceae', '殼斗科', 'Quercus glauca Thunb.', '青剛櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1813, 'Fagaceae', '殼斗科', 'Quercus glauca Thunb. var. kuyuensis J.C.Liao', '谷園青剛櫟', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1814, 'Fagaceae', '殼斗科', 'Quercus globosa (W.F.Lin & T.Liu) J.C.Liao ', '圓果青剛櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1815, 'Fagaceae', '殼斗科', 'Quercus globosa (W.F.Lin & T.Liu) J.C.Liao f. chiapautaiensis J.C.Liao', '佳保臺圓果青剛櫟', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1816, 'Fagaceae', '殼斗科', 'Quercus hypophaea Hayata', '灰背櫟', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1817, 'Fagaceae', '殼斗科', 'Quercus longinux Hayata', '錐果櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1818, 'Fagaceae', '殼斗科', 'Quercus longinux Hayata var. kuoi (J.C.Liao) C.F.Shen', '郭氏錐果櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1819, 'Fagaceae', '殼斗科', 'Quercus longinux Hayata var. lativiolacifolia (J.C.Liao ex J.C.Liao) J.C.Liao', '紫背錐果櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1820, 'Fagaceae', '殼斗科', 'Quercus morii Hayata', '赤柯', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1821, 'Fagaceae', '殼斗科', 'Quercus myrsinifolia Blume ', '黑櫟', 'DD');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1822, 'Fagaceae', '殼斗科', 'Quercus pachyloma Seemen ', '捲斗櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1823, 'Fagaceae', '殼斗科', 'Quercus repandifolia J.C.Liao', '波葉櫟', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1824, 'Fagaceae', '殼斗科', 'Quercus salicina Blume', '白背櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1825, 'Fagaceae', '殼斗科', 'Quercus sessilifolia Blume', '毽子櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1826, 'Fagaceae', '殼斗科', 'Quercus spinosa David ex Franch.', '高山櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1827, 'Fagaceae', '殼斗科', 'Quercus stenophylloides Hayata', '狹葉櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1828, 'Fagaceae', '殼斗科', 'Quercus tarokoensis Hayata', '太魯閣櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1829, 'Fagaceae', '殼斗科', 'Quercus tatakaensis Tomiya', '銳葉高山櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1830, 'Fagaceae', '殼斗科', 'Quercus variabilis Blume', '栓皮櫟', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1831, 'Salicaceae', '楊柳科', 'Casearia membranacea Hance', '薄葉嘉賜木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1832, 'Salicaceae', '楊柳科', 'Flacourtia rukam Zoll. & Merr.', '羅庚果', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1833, 'Salicaceae', '楊柳科', 'Homalium cochinchinensis (Lour.) Druce', '天料木', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1834, 'Salicaceae', '楊柳科', 'Idesia polycarpa Maxim.', '山桐子', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1835, 'Salicaceae', '楊柳科', 'Scolopia oldhamii Hance', '魯花樹', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1836, 'Salicaceae', '楊柳科', 'Xylosma congesta (Lour.) Merr.', '柞木', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1837, 'Flagellariaceae', '鞭藤科　', 'Flagellaria indica L.', '印度鞭藤', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1838, 'Papaveraceae', '罌粟科', 'Corydalis decumbens (Thunb.) Pers.', '伏莖紫堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1839, 'Papaveraceae', '罌粟科', 'Corydalis incisa (Thunb.) Pers.', '刻葉紫堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1840, 'Papaveraceae', '罌粟科', 'Corydalis koidzumiana Ohwi', '密花黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1841, 'Papaveraceae', '罌粟科', 'Corydalis ochotensis Turcz.', '疏花黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1842, 'Papaveraceae', '罌粟科', 'Corydalis ophiocarpa Hook. f. & Thomsson', '彎果黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1843, 'Papaveraceae', '罌粟科', 'Corydalis pallida (Thunb.) Pers.', '黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1844, 'Papaveraceae', '罌粟科', 'Corydalis pallida (Thunb.) Pers. var. sparsimamma (Ohwi) Ohwi', '凹子黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1845, 'Papaveraceae', '罌粟科', 'Corydalis racemosa (Thunb.) Pers.', '小花黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1846, 'Papaveraceae', '罌粟科', 'Corydalis tashiroi Makino', '臺灣黃堇', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1847, 'Papaveraceae', '罌粟科', 'Fumaria officinalis L.', '球果紫菫', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1848, 'Papaveraceae', '罌粟科', 'Fumaria parviflora Lam. ', '小花球果紫菫', 'NA');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1849, 'Gentianaceae', '龍膽科', 'Centaurium japonicum (Maxim.) Druce', '百金', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1850, 'Gentianaceae', '龍膽科', 'Centaurium pulchellum (Sw.) Druce var. altaicum (Griseb.) Kitag. et Hara', '百金花', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1851, 'Gentianaceae', '龍膽科', 'Gentiana arisanensis Hayata', '阿里山龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1852, 'Gentianaceae', '龍膽科', 'Gentiana bambuseti T. Y. Hsieh, T. C Hsu, S. M. Ku &
# C.-I Peng', '竹林龍膽', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1853, 'Gentianaceae', '龍膽科', 'Gentiana davidii Franch. var. formosana (Hayata) T. N. Ho', '臺灣龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1854, 'Gentianaceae', '龍膽科', 'Gentiana flavomaculata Hayata', '黃斑龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1855, 'Gentianaceae', '龍膽科', 'Gentiana flavomaculata Hayata var. yuanyanghuensis C. H. Chen & J. C. Wang', '鴛鴦湖龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1856, 'Gentianaceae', '龍膽科', 'Gentiana horaimontana Masam.', '高山龍膽', 'EN');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1857, 'Gentianaceae', '龍膽科', 'Gentiana itzershanensis T. S. Liu & Chiu C. Kuo', '伊澤山龍膽', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1858, 'Gentianaceae', '龍膽科', 'Gentiana kaohsiungensis C. H. Chen & J. C. Wang', '高雄龍膽', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1859, 'Gentianaceae', '龍膽科', 'Gentiana scabrida Hayata', '玉山龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1860, 'Gentianaceae', '龍膽科', 'Gentiana scabrida Hayata var. punctulata S. S. Ying', '黑斑龍膽', 'LC');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1861, 'Gentianaceae', '龍膽科', 'Gentiana tarokoensis C. H. Chen & J. C. Wang', '太魯閣龍膽', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1862, 'Gentianaceae', '龍膽科', 'Gentiana tatakensis Masam.', '塔塔加龍膽', 'VU');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1863, 'Gentianaceae', '龍膽科', 'Gentiana tentyoensis Masam.', '厚葉龍膽', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1864, 'Gentianaceae', '龍膽科', 'Gentiana tenuissima Hayata', '臺東龍膽', 'NT');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1865, 'Gentianaceae', '龍膽科', 'Lomatogonium chilaiensis C. H. Chen & J. C. Wang', '奇萊肋柱花', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1866, 'Menyanthaceae', '睡菜科', 'Nymphoides aurantiaca (Dalzell) Kuntze', '黃花莕菜', 'CR');
#
#
#     INSERT INTO redlist (id,family,family_zh,fullname,zh_name,category)
#     VALUES (1867, 'Menyanthaceae', '睡菜科', 'Nymphoides coreana (H. L'ev.) H. Hara', '小莕菜', 'VU');
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-41-e6339c224ed1> in <module>()
#       7     print(INSERT)
#       8     curs = conn.cursor()
# ----> 9     curs.execute(INSERT)
#      10     conn.commit()
#
# OperationalError: near "ev": syntax error

# %%
QUERY = '''SELECT * FROM redlist WHERE family ='Acanthaceae'; '''
curs.execute(QUERY)
acanthaceae = curs.fetchall()

# %%
acanthaceae
# Out:
# [(1,
#   'Acanthaceae',
#   '爵床科',
#   'Asystasia gangetica (L.) T.Anderson',
#   '赤道櫻草',
#   'NA'),
#  (2,
#   'Acanthaceae',
#   '爵床科',
#   'Asystasia gangetica (L.) T.Anderson ssp. micrantha (Nees) Ensermu',
#   '小花寬葉馬偕花',
#   'NA'),
#  (3,
#   'Acanthaceae',
#   '爵床科',
#   'Asystasiella neesiana (Nees) Lindau',
#   '尼氏擬馬偕花',
#   'VU'),
#  (4, 'Acanthaceae', '爵床科', 'Blechum pyramidatum (Lam.) Urb.', '賽山藍', 'NA'),
#  (5,
#   'Acanthaceae',
#   '爵床科',
#   'Codonacanthus pauciflorus (Nees) Nees',
#   '針刺草',
#   'LC'),
#  (6, 'Acanthaceae', '爵床科', 'Dicliptera chinensis (L.) Juss.', '華九頭獅子草', 'LC'),
#  (7, 'Acanthaceae', '爵床科', 'Dipteracanthus repens (L.) Hassk.', '蘆利草', 'LC'),
#  (8,
#   'Acanthaceae',
#   '爵床科',
#   'Hemigraphis cumingiana (Nees) Fern.-Vill.',
#   '直立半插花',
#   'VU'),
#  (9,
#   'Acanthaceae',
#   '爵床科',
#   'Hemigraphis primulifolia (Ness) Fern.-Vill.',
#   '恆春半插花',
#   'VU'),
#  (10,
#   'Acanthaceae',
#   '爵床科',
#   'Hemigraphis reptans (Forst.) Ander. ex Hemsl.',
#   '匍匐半插花',
#   'VU'),
#  (11,
#   'Acanthaceae',
#   '爵床科',
#   'Hygrophila corymbosa (Blume) Lindau',
#   '繖花水蓑衣',
#   'NA'),
#  (12,
#   'Acanthaceae',
#   '爵床科',
#   'Hygrophila difformis (L.f.) Blume',
#   '異葉水蓑衣',
#   'NA'),
#  (13, 'Acanthaceae', '爵床科', 'Hygrophila guianensis Nees ', '蓋亞那水蓑衣', 'NA'),
#  (14, 'Acanthaceae', '爵床科', 'Hygrophila lancea (Thunb.) Miq.', '水蓑衣', 'DD'),
#  (15, 'Acanthaceae', '爵床科', 'Hygrophila pogonocalyx Hayata ', '大安水蓑衣', 'EN'),
#  (16, 'Acanthaceae', '爵床科', 'Hygrophila polysperma T.Anderson', '小獅子草', 'EN'),
#  (17,
#   'Acanthaceae',
#   '爵床科',
#   'Hygrophila salicifolia (Vahl) Nees',
#   '柳葉水蓑衣',
#   'NT*'),
#  (18, 'Acanthaceae', '爵床科', 'Hygrophila stricta (Nees) Lindau', '刻脈水蓑衣', 'NA'),
#  (19,
#   'Acanthaceae',
#   '爵床科',
#   'Hypoestes cumingiana Benth. & Hook.',
#   '槍刀菜',
#   'LC'),
#  (20, 'Acanthaceae', '爵床科', 'Hypoestes purpurea R.Br.', '六角英', 'LC'),
#  (21, 'Acanthaceae', '爵床科', 'Justicia comata (L.) Lam.', '穗花爵床', 'NA'),
#  (22, 'Acanthaceae', '爵床科', 'Justicia gendarussa Brum.f.', '尖尾鳳', 'DD'),
#  (23,
#   'Acanthaceae',
#   '爵床科',
#   'Justicia procumbens L. var. hayatae (Yamam.) Ohwi',
#   '早田氏爵床',
#   'VU'),
#  (24,
#   'Acanthaceae',
#   '爵床科',
#   'Justicia procumbens L. var. hirsuta Yamam.',
#   '密毛爵床',
#   'VU'),
#  (25,
#   'Acanthaceae',
#   '爵床科',
#   'Justicia procumbens L. var. linearifolia Yamam.',
#   '狹葉爵床',
#   'VU'),
#  (26,
#   'Acanthaceae',
#   '爵床科',
#   'Justicia procumbens L. var. procumbens',
#   '爵床',
#   'LC'),
#  (27,
#   'Acanthaceae',
#   '爵床科',
#   'Justicia quadrifaria (Nees) T.Anderson',
#   '花蓮爵床',
#   'VU'),
#  (28, 'Acanthaceae', '爵床科', 'Kudoacanthus albonervosa Hosok.', '銀脈爵床', 'VU'),
#  (29,
#   'Acanthaceae',
#   '爵床科',
#   'Lepidagathis formosensis C.B.Clarke ex Hayata',
#   '臺灣鱗球花',
#   'LC'),
#  (30,
#   'Acanthaceae',
#   '爵床科',
#   'Lepidagathis inaequalis C.B.Clarke ex Elmer',
#   '卵葉鱗球花',
#   'LC'),
#  (31,
#   'Acanthaceae',
#   '爵床科',
#   'Lepidagathis secunda (Blanco) Nees',
#   '小琉球鱗球花',
#   'EN*'),
#  (32,
#   'Acanthaceae',
#   '爵床科',
#   'Lepidagathis stenophylla C.B.Clarke ex Hayata',
#   '柳葉鱗球花',
#   'NT'),
#  (33, 'Acanthaceae', '爵床科', 'Nelsonia canescens (Lam.) Spreng.', '瘤子草', 'NA'),
#  (34,
#   'Acanthaceae',
#   '爵床科',
#   'Peristrophe japonica (Thunb.) Bremek.',
#   '九頭獅子草',
#   'LC'),
#  (35,
#   'Acanthaceae',
#   '爵床科',
#   'Peristrophe roxburghiana (Schult.) Bremek.',
#   '長花九頭獅子草',
#   'LC'),
#  (36, 'Acanthaceae', '爵床科', 'Ruellia brittoniana Leonard', '紫花蘆利草', 'NA'),
#  (37,
#   'Acanthaceae',
#   '爵床科',
#   'Ruellia squarrosa (Fenzl) Schaffnit',
#   '蔓枝蘆莉草',
#   'NA'),
#  (38, 'Acanthaceae', '爵床科', 'Ruellia tuberosa L.', '塊根蘆利草', 'NA'),
#  (39, 'Acanthaceae', '爵床科', 'Rungia chinensis Benth.', '明萼草', 'LC'),
#  (40, 'Acanthaceae', '爵床科', 'Rungia taiwanensis T.Yamaz.', '臺灣明萼草', 'LC'),
#  (41,
#   'Acanthaceae',
#   '爵床科',
#   'Staurogyne concinnula (Hance) Kuntze',
#   '哈哼花',
#   'LC'),
#  (42,
#   'Acanthaceae',
#   '爵床科',
#   'Staurogyne debilis (T.Anderson) C.B.Clarke ex Mill.',
#   '菲律賓哈哼花',
#   'VU'),
#  (43, 'Acanthaceae', '爵床科', 'Strobilanthes cusia (Ness) Kuntze', '馬藍', 'LC'),
#  (44, 'Acanthaceae', '爵床科', 'Strobilanthes flexicaulis Hayata', '曲莖馬藍', 'LC'),
#  (45, 'Acanthaceae', '爵床科', 'Strobilanthes formosana S.Moore', '臺灣馬藍', 'LC'),
#  (46,
#   'Acanthaceae',
#   '爵床科',
#   'Strobilanthes lanyuensis Seok, C.F.Hsieh & J.Murata',
#   '蘭嶼馬蘭',
#   'EN'),
#  (47,
#   'Acanthaceae',
#   '爵床科',
#   'Strobilanthes longespicatus Hayata',
#   '長穗馬藍',
#   'LC'),
#  (48,
#   'Acanthaceae',
#   '爵床科',
#   'Strobilanthes penstemonoides T.Anderson',
#   '腺萼馬藍',
#   'LC'),
#  (49, 'Acanthaceae', '爵床科', 'Strobilanthes rankanensis Hayata', '蘭崁馬藍', 'LC'),
#  (50, 'Acanthaceae', '爵床科', 'Strobilanthes wallichii Nees ', '翅柄馬蘭', 'LC'),
#  (51, 'Acanthaceae', '爵床科', 'Thunbergia alata Bojer ex Sims', '黑眼花', 'NA'),
#  (52, 'Acanthaceae', '爵床科', 'Thunbergia fragrans Roxb. ', '碗花草', 'NA'),
#  (53, 'Acanthaceae', '爵床科', 'Thunbergia grandiflora Roxb.', '大鄧伯花', 'NA')]

# %%
import urllib

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/parse.py in urlencode(query, doseq, safe, encoding, errors, quote_via)
#     853             if len(query) and not isinstance(query[0], tuple):
# --> 854                 raise TypeError
#     855             # Zero-length sequences of all types will get here and succeed,
#
# TypeError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2dd79d87bbde> in <module>()
# ----> 1 urllib.parse.urlencode('www.google.com')
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/parse.py in urlencode(query, doseq, safe, encoding, errors, quote_via)
#     860             ty, va, tb = sys.exc_info()
#     861             raise TypeError("not a valid non-string sequence "
# --> 862                             "or mapping object").with_traceback(tb)
#     863
#     864     l = []
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/parse.py in urlencode(query, doseq, safe, encoding, errors, quote_via)
#     852             # non-empty strings will fail this
#     853             if len(query) and not isinstance(query[0], tuple):
# --> 854                 raise TypeError
#     855             # Zero-length sequences of all types will get here and succeed,
#     856             # but that's a minor nit.  Since the original implementation
#
# TypeError: not a valid non-string sequence or mapping object
