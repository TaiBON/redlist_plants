# %%
import psycopg2 as pg

import genlist_api                                                                                                                                                
g = genlist_api.Genlist()

# %%
DSN = 'dbname=nvdimp user=psilotum'
conn = pg.connect(DSN)

# %%
QUERY = 'SELECT fullname FROM twredlist2017;'
with conn:
    with conn.cursor() as curs:                                                                                                                           
        curs.execute(QUERY)
        fullnames = curs.fetchall()

# %%
for i in range(len(fullnames)):
    # replace double spaces
    if '  ' in fullnames[i][0]:
        replacedFullname = fullnames[i][0].replace('  ', ' ')
        UPDATE = '''
        UPDATE twredlist2017 SET
            fullname = '%s' 
        WHERE fullname = '%s'
        ''' % (replacedFullname, fullnames[i][0])
        print(replacedFullname)
        with conn:
            with conn.cursor() as curs:                                                                                                                           
                curs.execute(UPDATE)
    if 'ssp.' in fullnames[i][0]:
        replacedFullname = fullnames[i][0].replace('ssp.', 'subsp.')
        UPDATE = '''
        UPDATE twredlist2017 SET
            fullname = '%s' 
        WHERE fullname = '%s'
        ''' % (replacedFullname, fullnames[i][0])
        print(replacedFullname)
        with conn:
            with conn.cursor() as curs:                                                                                                                           
                curs.execute(UPDATE)
    # escape quote
    if "'" in fullnames[i][0]:
        replacedFullname = fullnames[i][0].replace("'", "''")
        UPDATE = '''
        UPDATE twredlist2017 SET
            fullname = '%s' 
        WHERE fullname = '%s'
        ''' % (replacedFullname, replacedFullname)
        print(replacedFullname)
        with conn:
            with conn.cursor() as curs:                                                                                                                           
                curs.execute(UPDATE)
    conn.commit()       

    if "\xa0" in fullnames[i][0]:
        print(fullnames[i][0].replace('\xa0', ' '))
        replacedFullname = fullnames[i][0].replace('\xa0', ' ')
        UPDATE = '''
        UPDATE twredlist2017 SET
            fullname = '%s' 
        WHERE fullname = '%s'
        ''' % (replacedFullname, fullnames[i][0])
        with conn:
            with conn.cursor() as curs:                                                                                                                           
                curs.execute(UPDATE)
            conn.commit()
# Out:
# Nymphoides coreana (H.L''ev.) H.Hara
# Erodium cicutarium (L.) L''Her.
# Broussonetia papyrifera (L.) L''Hér. ex Vent.
# Solanum viarum Dunal
# Phlegmariurus changii T.Y.Hsieh
# Elymus formosanus (Honda) Á.Löve
# Arabidopsis halleri (L.) O''Kane & Al-Shehbaz var. gemmifera (Matsum.) O''Kane & Al-Shehbaz
# Phaius tankervilleae (Banks ex L''Her.) Blume
# Bambusa dolichomerithalla Hayata cv.''Green stripe-stem'' W.C.Lin
# Bambusa dolichoclada Hayata cv.''Stripe'' W.C.Lin
# Erodium moschatum (L.) L''Her.

# %%
QUERY = 'SELECT fullname FROM twredlist2017;'
with conn:
    with conn.cursor() as curs:                                                                                                                           
        curs.execute(QUERY)
        fullnames = curs.fetchall()
for i in range(len(fullnames)):
    fname = fullnames[i][0]
    nameFormatted = g.fmtname(fname, split=True, format_type='custom', 
                                 italic_b="", italic_e="")
    if "'" in fname:
        fname = fname.replace("'", "''")
    if "'" in nameFormatted[0]:
        nameFormatted[0] = nameFormatted[0].replace("'", "''")
    if "'" in nameFormatted[1]:
        nameFormatted[1] = nameFormatted[1].replace("'", "''")
    UPDATE = '''
        UPDATE twredlist2017 SET
            name = '%s', authors = '%s'
        WHERE fullname = '%s'
        ''' % (nameFormatted[0], nameFormatted[1], fname)
    with conn:
        with conn.cursor() as curs:                                                                                                                           
            curs.execute(UPDATE)
    print(nameFormatted)
conn.commit()
# Out:
# ['Broussonetia papyrifera', "(L.) L''Hér. ex Vent."]
# ['Phlegmariurus changii', 'T.Y.Hsieh']
# ['Elymus formosanus', '(Honda) Á.Löve']
# ['Acer morrisonense', 'Hayata']
# ['Tabernaemontana pandacaqui', 'Poir.']
# ['Trachelospermum formosanum', 'Y.C.Liu & C.H.Ou']
# ['Trachelospermum gracilipes', 'Hook.f.']
# ['Begonia fenicis', 'Merr.']
# ['Trachelospermum lanyuense', 'C.E.Chang']
# ['Cuscuta australis', 'R.Br.']
# ['Ilex arisanensis', 'Yamam.']
# ['Ilex asprella', '(Hook. & Arn.) Champ.']
# ['Ilex bioritsensis', 'Hayata']
# ['Ilex crenata', 'Thunb.']
# ['Ilex ficoidea', 'Hemsl.']
# ['Digera muricata', '(L.) Mart.']
# ['Ilex formosana', 'Maxim.']
# ['Ilex goshiensis', 'Hayata']
# ['Erythrina variegata', 'L.']
# ['Osbeckia chinensis', 'L.']
# ['Ilex hayataiana', 'Loes.']
# ['Ilex integra', 'Thunb.']
# ['Ilex kusanoi', 'Hayata']
# ['Ficus nervosa', 'Heyne ex Roth']
# ['Ilex lonicerifolia var. matsudai', 'Yamam.']
# ['Ilex maximowicziana', 'Loes.']
# ['Ilex micrococca', 'Maxim.']
# ['Ilex pedunculosa', 'Miq.']
# ['Ilex pubescens', 'Hook. & Arn.']
# ['Ilex sugerokii var. brevipedunculata', '(Maxim.) S.Y.Hu']
# ['Ilex suzukii', 'S.Y.Hu']
# ['Ilex taiwanensis', 'Hayata']
# ['Dregea volubilis', '(L.f.) Benth.']
# ['Gymnema sylvestre', '(Retz.) Schultes']
# ['Heterostemma brownii', 'Hayata']
# ['Hoya carnosa', '(L.f.) R.Br.']
# ['Marsdenia formosana', 'Masam.']
# ['Marsdenia tinctoria', 'R.Br.']
# ['Telosma pallida', '(Roxb.) Craib']
# ['Tylophora lanyuensis', 'Y.C.Liu & F.Y.Lu']
# ['Tylophora ovata', '(Lindl.) Hook. ex Steud.']
# ['Tylophora taiwanensis', 'Hatus.']
# ['Ctenitis subglandulosa', '(Hance) Ching']
# ['Dryopteris kawakamii', 'Hayata']
# ['Asplenium formosae', 'H.Christ']
# ['Dryopteris maximowicziana', '(Miq.) C.Chr.']
# ['Dryopteris nidus', '(Baker) Li Bing Zhang']
# ['Dryopteris × holttumii ', 'Li Bing Zhang']
# ['Hypodematium crenatum', '(Forssk.) Kuhn']
# ['Lastreopsis tenera', '(R.Br.) Tindale']
# ['Pteridrys cnemidaria', '(H.Christ) C.Chr. & Ching']
# ['Tectaria coadunata', '(Wall. ex Hook. & Grev.) C.Chr.']
# ['Parsonia laevigata', '(Moon) Alston']
# ['Tectaria devexa', '(Kunze) Copel.']
# ['Tectaria dissecta', '(G.Forst.) Lellinger']
# ['Tectaria dubia', '(C.B.Clarke & Baker) Ching']
# ['Tectaria fauriei', 'Tagawa']
# ['Tectaria fuscipes', '(Wall. ex Bedd.) C.Chr.']
# ['Tectaria harlandii', '(Hook.) C.M.Kuo']
# ['Persicaria maculosa', 'Gray']
# ['Tectaria impressa', '(Fée) Holttum']
# ['Tectaria kusukusensis', '(Hayata) Lellinger']
# ['Tectaria multicaudata', 'Ching']
# ['Tectaria polymorpha', '(Wall. ex Hook.) Copel.']
# ['Tectaria rockii', 'C.Chr.']
# ['Tectaria simonsii', '(Baker) Ching']
# ['Tectaria subfuscipes', '(Tagawa) C.M.Kuo']
# ['Tectaria subtriphylla', '(Hook. & Arn.) Copel.']
# ['Asplenium adiantumnigrum', 'L.']
# ['Coniogramme procera', 'Fée']
# ['Trapa bispinosa', 'Roxb.']
# ['Asplenium antiquum', 'Makino']
# ['Cissus adnata', 'Roxb']
# ['Sium suave', 'Walt.']
# ['Asplenium australasicum', '(J.Sm.) Hook.']
# ['Cyperus distans', 'L.f.']
# ['Asplenium capillipes', 'Makino']
# ['Acalypha brachystachya', 'Hornem.']
# ['Quercus stenophylloides', 'Hayata']
# ['Asplenium crinicaule', 'Hance']
# ['Bauhinia championii', '(Benth.) Benth.']
# ['Asplenium cuneatiforme', 'H.Christ']
# ['Asplenium ensiforme', 'Wall. ex Hook. & Grev.']
# ['Asplenium lobulatum', 'Mett. ex Kuhn']
# ['Asplenium neolaserpitiifolium', 'Tardieu & Ching']
# ['Aralia bipinnata', 'Blanco']
# ['Asplenium nidus', 'L.']
# ['Hydrocotyle benguetensis', 'Elm.']
# ['Ulmus uyematsui', 'Hayata']
# ['Colocasia formosana', 'Hayata']
# ['Cyperus haspan', 'L.']
# ['Duranta erecta', 'L.']
# ['Asplenium normale', 'D.Don']
# ['Asplenium obscurum', 'Blume']
# ['Asplenium pifongiae', 'L.Y.Kuo, F.W.Li & Y.H.Chang']
# ['Asplenium polyodon', 'G.Forst.']
# ['Asplenium prolongatum', 'Hook.']
# ['Asplenium pulcherrimum', '(Baker) Ching']
# ['Asplenium ritoense', 'Hayata']
# ['Asplenium ruta-muraria', 'L.']
# ['Asplenium scolopendrium', 'L.']
# ['Asplenium septentrionale', '(L.) Hoffm.']
# ['Asplenium tenerum', 'G.Forst.']
# ['Ilex rotunda', 'Thunb.']
# ['Asplenium tenuicaule', 'Hayata']
# ['Asplenium tenuifolium', 'D.Don']
# ['Asplenium trichomanes', 'L.']
# ['Asplenium tripteropus', 'Nakai']
# ['Asplenium wilfordii', 'Mett. ex Kuhn']
# ['Asplenium wrightii', 'Eaton ex Hook.']
# ['Hydrilla verticillata', '(L.f.) Royle']
# ['Asplenium × shikokianum ', 'Makino']
# ['Asplenium × wangii ', 'C.M.Kuo']
# ['Asplenium yunnanense', 'Franch.']
# ['Acystopteris tenuisecta', '(Blume) Tagawa']
# ['Athyrium auriculatum', 'Seriz.']
# ['Eria corneri', 'Rchb.f.']
# ['Athyrium cryptogrammoides', 'Hayata']
# ['Athyrium drepanopterum', '(Kunze) A.Br. ex Milde']
# ['Athyrium epirachis', '(H.Christ) Ching']
# ['Athyrium foliolosum', '(Wall.) T.Moore ex R.Sim']
# ['Athyrium leiopodum', '(Hayata) Tagawa']
# ['Ruppia maritima', 'L.']
# ['Athyrium mupinense', 'Christ']
# ['Curcuma longa', 'L.']
# ['Athyrium nakanoi', 'Makino']
# ['Rhus succedanea var. succedanea', '']
# ['Athyrium oppositipinnum var. oppositipinnum', '']
# ['Athyrium otophorum', '(Miq.) Koidz.']
# ['Athyrium palustre', 'Seriz.']
# ['Athyrium pubicostatum', 'Ching & Z.Y.Liu']
# ['Athyrium puncticaule', '(Blume) T.Moore']
# ['Athyrium reflexipinnum', 'Hayata']
# ['Athyrium silvicola', 'Tagawa']
# ['Athyrium subrigescens', '(Hayata) Hayata ex H.Ito']
# ['Athyrium tozanense', '(Hayata) Hayata']
# ['Athyrium tripinnatum', 'Tagawa']
# ['Athyrium vidalii', '(Franch. & Sav.) Nakai']
# ['Athyrium × hohuanshanense ', 'Yoshik.']
# ['Athyrium × purpurascens ', '(Tagawa) Sa.Kurata']
# ['Cornopteris banajaoensis', '(C.Chr.) K.Iwats. & M.G.Price']
# ['Cornopteris decurrenti-alata var. decurrenti-alata', '']
# ['Cornopteris opaca', '(D.Don) Tagawa']
# ['Cornopteris philippinensis', 'M.Kato']
# ['Cystopteris fragilis', '(L.) Bernh.']
# ['Cystopteris moupinensis', 'Franch.']
# ['Deparia allantodioides', '(Bedd.) M.Kato']
# ['Deparia boryana', '(Willd.) M.Kato']
# ['Deparia formosana', '(Rosenst.) R.Sano']
# ['Deparia longipes', '(Ching) Shinohara']
# ['Deparia petersenii', '(Kunze) M.Kato']
# ['Deparia subfluvialis', '(Hayata) M.Kato']
# ['Diplazium amamianum', 'Tagawa']
# ['Diplazium asperum', 'Blume']
# ['Dryopteris alpestris', 'Tagawa']
# ['Diplazium chioui', 'T.C.Hsu']
# ['Diplazium crassiusculum', 'Ching']
# ['Diplazium dilatatum', 'Blume']
# ['Diplazium doederleinii', '(Luerss.) Makino']
# ['Diplazium donianum var. donianum', '']
# ['Diplazium esculentum var. esculentum', '']
# ['Diplazium esculentum var. pubescens', '(Link) Tardieu & C.Chr']
# ['Diplazium incomptum', 'Tagawa']
# ['Diplazium kappanensis', 'Hayata']
# ['Diplazium kawakamii', 'Hayata']
# ['Diplazium ketagalaniorum', 'T.C.Hsu']
# ['Diplazium laxifrons', 'Rosenst.']
# ['Diplazium lobatum', '(Tagawa) Tagawa']
# ['Diplazium maonense', 'Ching']
# ['Diplazium mettenianum', '(Miq.) C.Chr.']
# ['Diplazium okinawaensis', 'Tagawa']
# ['Diplazium okudairae', 'Makino']
# ['Diplazium petri', 'Tardieu']
# ['Diplazium phaeolepis', 'Tagawa']
# ['Diplazium proliferum', '(Lam.) Thouars']
# ['Asplenium serricula', 'Fée']
# ['Diplazium pullingeri', '(Baker) J.Sm.']
# ['Diplazium taiwanense', 'Tagawa']
# ['Diplazium viridissimum', 'Christ']
# ['Diplazium wichurae', '(Mett.) Diels']
# ['Gymnocarpium remote-pinnatum', '(Hayata) Ching']
# ['Rhachidosorus pulcher', '(Tagawa) Ching']
# ['Woodsia andersonii', '(Bedd.) Christ']
# ['Woodsia okamotoi', 'Tagawa']
# ['Woodsia polystichoides', 'D.C.Eaton']
# ['Azolla filiculoides', 'Lam.']
# ['Balanophora fungosa', 'J.R.Forst. & G.Forst.']
# ['Balanophora harlandii', 'Hook.f.']
# ['Impatiens devolii', 'T.C.Huang']
# ['Impatiens tayemonii', 'Hayata']
# ['Impatiens uniflora', 'Hayata']
# ['Anredera cordifolia', '(Ten.) Steenis']
# ['Basella alba', 'L.']
# ['Begonia aptera', 'Blume']
# ['Begonia austrotaiwanensis', 'Y.K.Chen & C.I Peng']
# ['Begonia chitoensis', 'T.S.Liu & M.J.Lai']
# ['Begonia chuyunshanensis', 'C.I Peng & Y.K.Chen']
# ['Hymenasplenium apogamum', '(N.Murak. & Hatan.) Nakaike']
# ['Hymenasplenium cataractarum', '(Rosenst.) N.Murakami']
# ['Hymenasplenium cheilosorum', '(Kunze ex Mett.) Tagawa']
# ['Hymenasplenium obliquissimum', '(Hayata) Sugimoto']
# ['Hymenasplenium subnormale', '(Copel.) Nakaike']
# ['Hymenasplenium unilaterale', '(Lam.) Hayata']
# ['Anisocampium cumingianum', 'C.Presl']
# ['Anisocampium niponicum', '(Mett.) Yea C.Liu, W.L.Chiou & M.Kato']
# ['Begonia formosana', '(Hayata) Masam.']
# ['Begonia lukuana', 'Y.C.Liu & C.H.Ou']
# ['Begonia nantoensis', 'M.J.Lai & N.J.Chung']
# ['Begonia palmata', 'D.Don']
# ['Begonia pinglinensis', 'C.I Peng']
# ['Begonia ravenii', 'C.I Peng & Y.K.Chen']
# ['Begonia semperflorens-cultorum', 'Hort.']
# ['Begonia taiwaniana', 'Hayata']
# ['Begonia wutaiana', 'C.I Peng & Y.K.Chen']
# ['Begonia × buimontana ', 'Yamam.']
# ['Begonia × chungii ', 'C.I Peng & S.M.Ku']
# ['Begonia × taipeiensis ', 'C.I Peng']
# ['Berberis aristatoserrulata', 'Hayata']
# ['Berberis hayatana', 'Mizush.']
# ['Berberis kawakamii', 'Hayata']
# ['Berberis mingetsuensis', 'Hayata']
# ['Berberis morrisonensis', 'Hayata']
# ['Berberis pengii', 'C.C.Yu & K.F.Chung']
# ['Berberis ravenii', 'C.C.Yu & K.F.Chung']
# ['Berberis schaaliae', 'C.C.Yu & K.F.Chung']
# ['Dysosma pleiantha', '(Hance) Woodson']
# ['Mahonia japonica', '(Thunb.) DC.']
# ['Carpinus rankanensis', 'Hayata']
# ['Woodwardia japonica', '(L.f.) Sm.']
# ['Woodwardia kempii', 'Copel.']
# ['Woodwardia unigemmata', '(Makino) Nakai']
# ['Bombax ceiba', 'L.']
# ['Pachira aquatica', 'Aubl.']
# ['Bothriospermum zeylanicum', '(J.Jacq.) Druce']
# ['Coldenia procumbens', 'L.']
# ['Cordia dichotoma', 'G.Forst.']
# ['Cynoglossum alpestre', 'Ohwi']
# ['Cynoglossum furcatum', 'Wall.']
# ['Ulmus parvifolia', 'Jacq.']
# ['Cynoglossum lanceolatum', 'Forssk.']
# ['Ehretia acuminata', 'R.Br.']
# ['Ehretia dicksonii', 'Hance']
# ['Ehretia microphylla', 'Lam.']
# ['Asplenium pekinense', 'Hance']
# ['Ehretia philippinensis', 'A.DC.']
# ['Ehretia resinosa', 'Hance']
# ['Heliotropium formosanum', 'I.M.Johnst.']
# ['Heliotropium indicum', 'L.']
# ['Lithospermum zollingeri', 'DC.']
# ['Myosotis arvensis', '(L.) Hill']
# ['Symphytum officinale', 'L.']
# ['Thyrocarpus sampsonii', 'Hance']
# ['Trichodesma calycosum', 'Collett & Hemsl.']
# ['Trigonotis formosana', 'Hayata']
# ['Trigonotis nankotaizanensis', '(Sasaki) Masam. & Ohwi ex Masam.']
# ['Buxus liukiuensis', 'Makino']
# ['Buxus microphylla subsp. sinica', '(Rehder & E.H.Wils.) Hatus.']
# ['Pachysandra axillaris', 'Franch.']
# ['Sarcococca saligna', '(D.Don.) Müll.Arg.']
# ['Brasenia schreberi', 'J.F.Gmel.']
# ['Cabomba caroliniana', 'A.Gray']
# ['Cabomba furcata', 'Schult. & Schult.f.']
# ['Cereus repandus', '(L.) Mill.']
# ['Hylocereus undatus', '(Haw.) Britton & Rose']
# ['Opuntia dillenii', '(Ker) Haw.']
# ['Callitriche palustris var. oryzetorum', '(Petrov) Lansdown']
# ['Callitriche palustris var. palustris', '']
# ['Callitriche peploides', 'Nutt.']
# ['Callitriche verna', 'L.']
# ['Adenophora morrisonensis subsp. Morrisonensis', '']
# ['Adenophora morrisonensis subsp. uehatae', '(Yamam.) Lammers']
# ['Adenophora triphylla', '(Thunb.) A.DC.']
# ['Campanula dimorphantha', 'Schweinf.']
# ['Codonopsis kawakamii', 'Hayata']
# ['Cyclocodon lancifolius', '(Roxb.) Kurz']
# ['Hippobroma longiflora', '(L.) G.Don']
# ['Lobelia alsinoides subsp. hancei', '(H.Hara) Lammers']
# ['Lobelia chinensis', 'Lour.']
# ['Lobelia cliffortiana', 'L.']
# ['Lobelia seguinii', 'H.Lév. & Vaniot']
# ['Lobelia zeylanica', 'L.']
# ['Peracarpa carnosa', '(Wall.) Hook.f. & Thomson']
# ['Capparis lanceolaris', 'DC.']
# ['Capparis pubiflora', 'DC.']
# ['Capparis sabiaefolia', 'Hook.f. & Thoms.']
# ['Cleome gynandra', 'L.']
# ['Cleome rutidosperma', 'DC.']
# ['Cleome viscosa', 'L.']
# ['Lonicera acuminata', 'Wall.']
# ['Lonicera apodantha', 'Ohwi']
# ['Lonicera hypoglauca', 'Miq.']
# ['Lonicera japonica', 'Thunb.']
# ['Lonicera macrantha', '(D.Don) Spreng.']
# ['Lonicera oiwakensis', 'Hayata']
# ['Sambucus chinensis', 'Lindl.']
# ['Viburnum aboricolum', 'Hayata']
# ['Viburnum betulifolium', 'Batal.']
# ['Viburnum erosum', 'Thunb.']
# ['Viburnum formosanum', 'Hayata']
# ['Viburnum integrifolium', 'Hayata']
# ['Viburnum japonicum', '(Thunb.) Spreng.']
# ['Viburnum luzonicum', 'Rolfe']
# ['Viburnum odoratissimum', 'Ker']
# ['Viburnum parvifolium', 'Hayata']
# ['Viburnum propinquum', 'Hemsl.']
# ['Viburnum sphaerocarpum', 'Y.C.Liu & C.H.Ou']
# ['Viburnum sympodiale', 'Graebn.']
# ['Blechnidium melanopus', '(Hook.) T.Moore']
# ['Blechnopsis orientalis', '(L.) C.Presl']
# ['Viburnum taitoense', 'Hayata']
# ['Viburnum urceolatum', 'Siebold & Zucc.']
# ['Arenaria subpilosa', '(Hayata) Ohwi']
# ['Arenaria takasagomontana', '(Masam.) S.S.Ying']
# ['Asarum crassusepalum', 'S.F.Huang']
# ['Cerastium formosanum', 'Ohwi']
# ['Cerastium glomeratum', 'Thuill.']
# ['Cerastium holosteoides var. hallaisanense', '(Nakai) Mizush.']
# ['Cerastium parvipetalum', 'Hosok.']
# ['Cucubalus baccifer', 'L.']
# ['Dianthus palinensis', 'S.S.Ying']
# ['Dianthus superbus var. longicalycinus', '(Maxim.) Will.']
# ['Drymaria cordata', '(L.) Willd. ex Schult.']
# ['Drymaria villosa', 'Cham. & Schltdl.']
# ['Moehringia trinervia', '(L.) Clairv.']
# ['Polycarpaea corymbosa', '(L.) Lam.']
# ['Sagina japonica', '(Sw. ex Steud.) Ohwi']
# ['Sagina maxima', 'A.Gray']
# ['Sagina procumbens', 'L.']
# ['Silene fortunei var. kiruninsularis', '(Masam.) S.S.Ying']
# ['Silene gallica', 'L.']
# ['Silene glabella', '(Ohwi) S.S.Ying']
# ['Silene morii', 'Hayata']
# ['Spergula arvensis', 'L.']
# ['Stellaria alsine var. undulata', '(Thunb.) Ohwi']
# ['Stellaria aquatica', '(L.) Scop.']
# ['Stellaria arisanensis', '(Hayata) Hayata']
# ['Stellaria media', '(L.) Vill.']
# ['Stellaria saxatilis', 'Buch.-Ham. ex D.Don']
# ['Casuarina equisetfolia', 'L.']
# ['Poikilospermum acuminata', '(Trécul) Merr.']
# ['Celastrus hindsii', 'Benth.']
# ['Tournefortia argentea', 'L.f.']
# ['Tournefortia sarmentosa', 'Lam.']
# ['Limnocharis flava', '(L.) Buch.']
# ['Celastrus kusanoi', 'Hayata']
# ['Celastrus punctatus', 'Thunb.']
# ['Euonymus carnosus', 'Hemsl.']
# ['Euonymus cochinchinensis', 'Pierre']
# ['Euonymus japonicus', 'Thunb.']
# ['Euonymus laxiflorus', 'Champ. ex Benth.']
# ['Euonymus oxyphyllus', 'Miq.']
# ['Euonymus pallidifolia', 'Hayata']
# ['Euonymus spraguei', 'Hayata']
# ['Microtropis fokienensis', 'Dunn']
# ['Microtropis japonica', '(Franch. & Sav.) Hallier f.']
# ['Perrottetia arisanensis', 'Hayata']
# ['Tripterygium wilfordii', 'Hook.f.']
# ['Ceratophyllum kossinskyi', 'Kuzen.-Proch']
# ['Ceratophyllum oryzetorum', 'Kom.']
# ['Atriplex maximowicziana', 'Makino']
# ['Atriplex nummularia', 'Lindl.']
# ['Chenopodium acuminatum subsp. virgatum', '(Thunb.) Kitam.']
# ['Ainsliaea macroclinidioides', 'Hayata']
# ['Ainsliaea secundiflora', 'Hayata']
# ['Ambrosia artemisiifolia', 'L.']
# ['Ambrosia psilostachya', 'DC.']
# ['Anaphalis horaimontana', 'Masam.']
# ['Anaphalis morrisonicola', 'Hayata']
# ['Anaphalis royleana', 'DC.']
# ['Artemisia annua', 'L.']
# ['Artemisia anomala', 'S.Moore']
# ['Artemisia capillaris', 'Thunb.']
# ['Artemisia fukudo', 'Makino']
# ['Artemisia indica', 'Willd.']
# ['Artemisia japonica', 'Thunb.']
# ['Artemisia kawakamii', 'Hayata']
# ['Artemisia lancea', 'Van.']
# ['Artemisia niitakayamensis', 'Hayata']
# ['Artemisia oligocarpa', 'Hayata']
# ['Abelia chinensis var. ionandra', '(Hayata) Masam.']
# ['Artemisia simulans', 'Pamp.']
# ['Artemisia somai var. somai', '']
# ['Artemisia tsugitakaensis', '(Kitam.) Ling & Y.R.Ling']
# ['Aster ageratoides', 'Turcz.']
# ['Aster altaicus', 'Willd.']
# ['Aster chingshuiensis', 'Y.C.Liu & C.H.Ou']
# ['Aster itsunboshi', 'Kitam.']
# ['Aster lasiocladus', 'Hayata']
# ['Aster morrisonensis', 'Hayata']
# ['Aster oldhamii', 'Hemsl.']
# ['Aster shimadai', '(Kitam.) Nemoto']
# ['Aster subulatus var. sandwicensis', '(A.Gray) A.G.Jones']
# ['Aster subulatus var. subulatus', '']
# ['Aster taiwanensis', 'Kitam.']
# ['Aster taoyuenensis', 'S.S.Ying']
# ['Bidens bipinnata', 'L.']
# ['Bidens biternata', '(Lour.) Merr. & Sherff']
# ['Bidens pilosa var. minor', '(Blume) Sherff']
# ['Bidens pilosa var. pilosa', '']
# ['Bidens tripartita', 'L.']
# ['Blumea conspicua', 'Hayata']
# ['Blumea hieracifolia', '(D.Don) DC.']
# ['Blumea lacera', '(Burm.f.) DC.']
# ['Blumea lanceolaria', '(Roxb.) Druce']
# ['Blumea linearis', 'C.I Peng & W.P.Leu']
# ['Blumea mollis', '(D.Don) Merr.']
# ['Blumea riparia var. megacephala', 'Randeria']
# ['Blumea viscosa', '(Mill.) V.M.Badillo']
# ['Calyptocarpus vialis', 'Less.']
# ['Carpesium abrotanoides', 'L.']
# ['Carpesium cernuum', 'L.']
# ['Carpesium minus', 'Hemsl.']
# ['Carpesium nepalense', 'Less.']
# ['Centipeda minima', '(L.) A.Br. & Asch.']
# ['Centratherum punctatum', 'Cass.']
# ['Polycarpon tetraphyllum', '(L.) L.']
# ['Chromolaena odorata', '(L.) R.M.King & H.Rob.']
# ['Cichorium intybus', 'L.']
# ['Cirsium brevicaule', 'A.Gray']
# ['Bellis perennis', 'L.']
# ['Cirsium japonicum var. australe', 'Kitam.']
# ['Cirsium kawakamii', 'Hayata']
# ['Cirsium lineare', '(Thunb.) Sch.Bip.']
# ['Cirsium morii', 'Hayata']
# ['Cirsium suzukii', 'Kitam.']
# ['Clibadium surinamense', 'L.']
# ['Conyza aegyptiaca', '(L.) Aiton']
# ['Conyza canadensis var. canadensis', '']
# ['Conyza canadensis var. pusilla', '(Nutt.) Cronq.']
# ['Conyza japonica', '(Thunb.) Less.']
# ['Conyza leucantha', '(D.Don) Ludlow & P.H.Raven']
# ['Coreopsis tinctoria', 'Nutt.']
# ['Cotula australis', '(Sieber ex Spreng.) Hook.f.']
# ['Cotula hemisphaerica', 'Wall. ex Benth. & Hook.']
# ['Crepidiastrum taiwanianum', 'Nakai']
# ['Crossostephium chinense', '(L.) Makino']
# ['Dendranthema arisanense', '(Hayata) Y.Ling & C.Shih']
# ['Dendranthema indicum', '(L.) Des Moul.']
# ['Dendranthema lavandulifolium var. tomentellum', '(Hand.-Mazz.) Y.Ling & C.Shih']
# ['Dendranthema morii', '(Hayata) Kitam.']
# ['Echinops grijsii', 'Hance']
# ['Eclipta prostrata', '(L.) L.']
# ['Eclipta zippeliana', 'Blume']
# ['Elephantopus mollis', 'Kunth']
# ['Elephantopus scaber', 'L.']
# ['Emilia fosbergii', 'Nicolson']
# ['Emilia praetermissa', 'Milne-Redh.']
# ['Emilia sonchifolia var. javanica', '(Burm.f.) Mattfeld']
# ['Epaltes australis', 'Less.']
# ['Erechtites hieraciifolius var. hieraciifolius', '']
# ['Spergularia marina', '(L.) Griseb.']
# ['Erechtites valerianifolia', '(Link ex Wolf) Less. ex DC.']
# ['Erigeron annuus', '(L.) Pers.']
# ['Erigeron bellioides', 'DC.']
# ['Erigeron morrisonensis var. morrisonensis', '']
# ['Eupatorium amabile', 'Kitam.']
# ['Eupatorium clematideum var. clematideum', '']
# ['Eupatorium formosanum', 'Hayata']
# ['Eupatorium hualienense', 'C.H.Ou, S.W.Chung & C.I Peng']
# ['Eupatorium kiirunense', '(Kitam.) C.H.Ou & S.W.Chung']
# ['Eupatorium lindleyanum', 'DC.']
# ['Eupatorium shimadaiKitam.', '']
# ['Farfugium japonicum var. formosanum', '(Hayata) Kitam.']
# ['Farfugium japonicum var. japonicum', '']
# ['Flaveria bidentis', '(L.) Kuntze']
# ['Flaveria linearis', 'Lag.']
# ['Galinsoga parviflora', 'Cav.']
# ['Galinsoga quadriradiata', 'Ruiz & Pav.']
# ['Glossocardia bidens', '(Retz.) Veldkamp']
# ['Gnaphalium hypoleucum var. amoyense', '(Hance) Hand.-Mazz.']
# ['Gnaphalium involucratum var. ramosum', 'DC.']
# ['Gnaphalium involucratum var. simplex', 'DC.']
# ['Gnaphalium japonicum', 'Thunb.']
# ['Gnaphalium luteoalbum subsp. affine', '(D.Don) Koster']
# ['Gnaphalium pensylvanicum', 'Willd.']
# ['Gnaphalium polycaulon', 'Pers.']
# ['Gnaphalium purpureum', 'L.']
# ['Gnaphalium spicatum', 'Lam.']
# ['Guizotia abyssinica', '(L.f.) Cass.']
# ['Gymnocoronis spilanthoides', '(D.Don ex Hook. & Arn.) DC.']
# ['Gynura bicolor', '(Roxb. & Willd.) DC.']
# ['Gynura elliptica', 'Yabe & Hayata']
# ['Gynura japonica', '(Thunb.) Juel']
# ['Gerbera anandria', '(L.) Sch.Bip']
# ['Helianthus debilis subsp. cucumerifolius', '(Torrey & A.Gray) Heiser']
# ['Hieracium morii', 'Hayata']
# ['Hypochaeris chillensis', '(Kunth) Britton']
# ['Hypochaeris glabra', 'L.']
# ['Hypochaeris radicata', 'L.']
# ['Ixeridium laevigatum', '(Blume) J.H.Pak & Kawano']
# ['Ixeridium transnokoense', '(Y. Sasaki) J.H.Pak & Kawano']
# ['Ixeris chinensis', '(Thunb.) Nakai']
# ['Ixeris repens', '(L.) A.Gray']
# ['Ixeris stolonifera', 'A.Gray']
# ['Ixeris tamagawaensis', '(Makino) Kitam.']
# ['Lagenophora lanata', 'A.Cunn.']
# ['Laggera alata', '(D.Don) Sch.Bip. ex Oliv.']
# ['Lapsanastrum takasei', '(Sasaki) J.H.Pak & K.Bremer']
# ['Leontopodium microphyllum', 'Hayata']
# ['Leucanthemum vulgare', 'H.J.Lam.']
# ['Ligularia japonica', '(Thunb.) Less.']
# ['Ligularia kojimae', 'Kitam.']
# ['Ligularia stenocephala', '(Maxim.) Matsum. & Koidz.']
# ['Microglossa pyrifolia', '(Lam.) Kuntze']
# ['Mikania cordata', '(Burm.f.) B.L.Rob.']
# ['Nemosenecio formosanus', '(Kitam.) B.Nord.']
# ['Paraprenanthes sororia', '(Miq.) C.Shih']
# ['Parasenecio hwangshanica', '(Ling) C.I Peng & S.W.Chung']
# ['Parasenecio monantha', '(Diels) C.I Peng & S.W.Chung']
# ['Parthenium hysterophorus', 'L.']
# ['Pertya simozawai', 'Masam.']
# ['Picris hieracioides subsp. morrisonensis', '(Hayata) Kitam.']
# ['Pluchea carolinensis', '(Jacq.) G.Don']
# ['Pluchea indica', '(L.) Less.']
# ['Pluchea pteropoda', 'Hemsl.']
# ['Pluchea sagittalis', '(Lam.) Cabera']
# ['Praxelis clematidea', '(Griseb.) R.M.King & H.Rob.']
# ['Pseudelephantopus spicatus', '(Juss.) C.F.Baker']
# ['Pterocypsela formosana', '(Maxim.) C.Shih']
# ['Pterocypsela indica', '(L.) C.Shih']
# ['Argyranthemum frutescens', '(L.) Sch.Bip.']
# ['Rhynchospermum verticillatum', 'Reinw.']
# ['Saussurea glandulosa', 'Kitam.']
# ['Saussurea japonica', '(Thunb.) DC.']
# ['Saussurea kanzanensis', 'Kitam.']
# ['Saussurea kiraisiensis', 'Masam.']
# ['Senecio inaequidens', 'DC.']
# ['Senecio kuanshanensis', 'C.I Peng & S.W.Chung']
# ['Senecio morrisonensis', 'Hayata']
# ['Senecio nemorensis var. dentatus', '(Kitam.) H.Koyama']
# ['Senecio scandens var. incisus', 'Franch.']
# ['Senecio taitungensis', 'S.S.Ying']
# ['Senecio tarokoensis', 'C.I Peng']
# ['Senecio vulgaris', 'L.']
# ['Sigesbeckia orientalis', 'L.']
# ['Solidago virgaurea var. leiocarpa', '(Benth.) A.Gray']
# ['Soliva anthemifolia', '(Juss.) R.Br. ex Less.']
# ['Soliva pterosperma', '(Juss.) Less.']
# ['Sonchus asper', '(L.) Hill']
# ['Sphaeranthus africanus', 'L.']
# ['Syneilesis subglabrata', '(Yamam. & Sasaki) Kitam.']
# ['Tagetes minuta', 'L.']
# ['Taraxacum officinale', 'Weber']
# ['Tephroseris kirilowii', '(Turcz. ex DC.) Holub']
# ['Tephroseris taitoensis', '(Hayata) Holub']
# ['Vernonia cinerea var. cinerea', '']
# ['Vernonia cinerea var. parviflora', '(Reinw.) DC.']
# ['Vernonia elliptica', 'DC.']
# ['Vernonia gratiosa', 'Hance']
# ['Vernonia maritima', 'Merr.']
# ['Wedelia biflora var. biflora', '']
# ['Wedelia biflora var. ryukyuensis', 'H.Koyama']
# ['Sonchus arvensis', 'L.']
# ['Wedelia chinensis', '(Osbeck) Merr.']
# ['Wedelia prostrata var. robusta', 'Makino']
# ['Wedelia trilobata', '(L.) Hitchc.']
# ['Xanthium strumarium', 'L.']
# ['Youngia japonica subsp. japonica', '']
# ['Youngia japonica subsp. longiflora', 'Babc. & Stebbins']
# ['Connarus subinaequifolius', 'Elmer']
# ['Rourea minor', '(Gaertn.) Leenhouts']
# ['Argyreia formosana', 'Ishigami ex T.Yamaz.']
# ['Argyreia nervosa', '(Burm.f.) Boj.']
# ['Calystegia soldanella', '(L.) R.Br.']
# ['Cuscuta campestris', 'Yunck.']
# ['Cuscuta chinensis', 'Lam.']
# ['Cuscuta japonica var. japonica', '']
# ['Dichondra micrantha', 'Urb.']
# ['Erycibe henryi', 'Prain']
# ['Evolvulus alsinoides', '(L.) L.']
# ['Evolvulus nummularius', '(L.) L.']
# ['Hewittia malabarica', '(L.) Suresh']
# ['Ipomoea alba', 'L.']
# ['Ipomoea batatas', '(L.) Lam.']
# ['Ipomoea biflora', '(L.) Persoon']
# ['Ipomoea cairica', '(L.) Sweet']
# ['Ipomoea hederacea', '(L.) Jacq.']
# ['Ipomoea imperati', '(Vahl) Griseb.']
# ['Ipomoea indica', '(Burm.f.) Merr.']
# ['Ipomoea littoralis', 'Blume']
# ['Ipomoea mauritiana', 'Jacq.']
# ['Ipomoea nil', '(L.) Roth.']
# ['Ipomoea obscura', '(L.) Ker Gawl.']
# ['Ipomoea pes-tigridis', 'L.']
# ['Ipomoea polymorpha', 'Roem. & Schult.']
# ['Ipomoea purpurea', '(L.) Roth.']
# ['Ipomoea quamoclit', 'L.']
# ['Ipomoea triloba', 'L.']
# ['Ipomoea wrightii', 'A.Gray']
# ['Jacquemontia paniculata', '(Burm.f.) Hallier f.']
# ['Jacquemontia tamnifolia', '(L.) Griseb.']
# ['Hemistepta lyrata', '(Bunge) Bunge']
# ['Ixeris polycephala', 'Cass.']
# ['Lepistemon binectariferum var. trichocarpum', '(Gagnep.) Ooststr.']
# ['Lepistemon intermedius', 'Hallier f.']
# ['Merremia cissoides', '(Lam.) Hallier f.']
# ['Merremia gemella', '(Burm.f.) Hallier f.']
# ['Merremia hirta', '(L.) Merr.']
# ['Merremia quinata', '(R.Br.) Oostst.']
# ['Merremia similis', 'Elmer']
# ['Merremia tuberosa', '(L.) Rendle']
# ['Merremia vitifolia', '(Burm.f.) Hallier f.']
# ['Operculina turpethum', '(L.) S.Manso']
# ['Xenostegia tridentata', '(L.) D.F.Austin & Staples']
# ['Coriaria japonica subsp. intermedia', '(Matsum.) T.C.Huang & S.F.Huang']
# ['Aucuba chinensis', 'Benth.']
# ['Aucuba japonica', 'Thunb.']
# ['Helwingia japonica subsp. taiwaniana', 'Y.P. Yang & H.Y. Liu']
# ['Swida controversa', '(Hemsl.) Soják']
# ['Swida macrophylla', '(Wall.) Soják']
# ['Bryophyllum delagoense', '(Eckl. & Zeyh.) Druce']
# ['Hylotelephium subcapitatum', '(Hayata) H.Ohba']
# ['Sedum actinocarpum', 'Yamam.']
# ['Sedum bulbiferum', 'Makino']
# ['Sedum cryptomerioides', 'Bart. & Yamam.']
# ['Sedum emarginatum', 'Migo']
# ['Sedum formosanum', 'N.E.Br.']
# ['Sedum mexicanum', 'Britt.']
# ['Sedum microsepalum', 'Hayata']
# ['Sedum morrisonense', 'Hayata']
# ['Sedum nokoense', 'Yamam.']
# ['Sedum sekiteiense', 'Yamam.']
# ['Sedum stellariaefolium', 'Franch.']
# ['Kalimeris hispida', '(Thunb.) Nees']
# ['Pectis prostrata', 'Cavanilles']
# ['Sedum uniflorum', 'Hook. & Arn.']
# ['Arabis lyrata subsp. kamchatica', '(Fisch. ex DC.) Hultén']
# ['Arabis alpina var. formosana', 'Masam. ex S.F.Huang']
# ['Arabis serrata', 'Franch. & Sav.']
# ['Arabis stelleris var. japonica', '(A.Gray) F.Schmidt']
# ['Barbarea orthoceras', 'Ledeb.']
# ['Barbarea taiwaniana', 'Ohwi']
# ['Capsella bursa-pastoris', '(L.) Medic.']
# ['Asarum epigynum', 'Hayata']
# ['Cardamine circaeoides', 'Hook.f. & Thomson']
# ['Cardamine flexuosa', 'With.']
# ['Cardamine impatiens', 'L.']
# ['Cardamine nipponica', 'Franch. & Sav.']
# ['Coronopus didymus', '(L.) Sm.']
# ['Coronopus integrifolius', '(DC.) Prantl']
# ['Draba sekiyana', 'Ohwi']
# ['Eutrema japonica', '(Miq.) Koidz.']
# ['Lepidium bonariense', 'L.']
# ['Lepidium virginicum', 'L.']
# ['Nasturtium officinale', 'R.Br.']
# ['Raphanus raphanistrum subsp. sativus', '(L.) Domin']
# ['Rapistrum rugosum', '(L.) All.']
# ['Rorippa austriaca', '(Crantz) Besser']
# ['Rorippa cantoniensis', '(Lour.) Ohwi']
# ['Rorippa sylvestris', '(L.) Besser']
# ['Sisymbrium irio', 'L.']
# ['Neoalsomitra integrifolia', '(Cogn.) Hutch.']
# ['Sechium edule', '(Jacq.) Sw.']
# ['Solena amplexicaulis', '(Lam.) Gandhi']
# ['Thladiantha nudiflora', 'Hemsl. ex Forbes & Hemsl.']
# ['Thladiantha punctata', 'Hayata']
# ['Trichosanthes cucumeroides', '(Ser.) Maxim. ex Franch. & Sav.']
# ['Trichosanthes homophylla', 'Hayata']
# ['Trichosanthes laceribracteata', 'Hayata']
# ['Trichosanthes quinquangulata', 'A.Gray']
# ['Hymenasplenium filipes', '(Copel.) Sugimoto']
# ['Zehneria japonica', '(Thunb.) H.Y.Liu']
# ['Zehneria mucronata', '(Blume) Miq.']
# ['Chamaecyparis formosensis', 'Mastum.']
# ['Chamaecyparis obtusa var. formosana', '(Hayata) Rehder']
# ['Juniperus chinensis var. taiwanensis', 'R.P.Adams & C.F.Hsieh']
# ['Juniperus formosana', 'Hayata']
# ['Asarum hypogynum', 'Hayata']
# ['Juniperus squamata', 'Buch.-Ham. ex Lamb.']
# ['Cycas taitungensis', 'C.F.Shen et al.']
# ['Davallia trichomanoides', 'Blume']
# ['Leucostegia truncata', '(D.Don) Fraser-Jenk.']
# ['Dennstaedtia hirsuta', '(Sw.) Mett. ex Miq.']
# ['Dennstaedtia scandens', '(Blume) Moore']
# ['Dennstaedtia smithii', '(Hook.) Moore']
# ['Histiopteris incisa', '(Thunb.) J.Sm.']
# ['Hypolepis alpina', '(Blume) Hook.']
# ['Hypolepis pallida', '(Blume) Hook.']
# ['Hypolepis punctata', '(Thunb.) Mett. ex Kuhn']
# ['Microlepia calvescens', '(Wall. ex Hook.) C.Presl']
# ['Microlepia hookeriana', '(Wall. ex Hook.) C.Presl']
# ['Microlepia intramarginalis', '(Tagawa) Seriz.']
# ['Microlepia krameri', 'C.M.Kuo']
# ['Drosera peltata', 'Sm.']
# ['Microlepia marginata var. bipinnata', 'Makino']
# ['Microlepia nepalensis', '(Spreng.) Fraser-Jenk., Kandel & Pariyar']
# ['Microlepia obtusiloba', 'Hayata']
# ['Microlepia rhomboidea', '(Wall. ex Kunze) Prantl']
# ['Microlepia sinostrigosa', 'Ching']
# ['Microlepia speluncae', '(L.) Moore']
# ['Microlepia strigosa', '(Thunb.) C.Presl']
# ['Microlepia trapeziformis', '(Roxb.) Kuhn']
# ['Monachosorum henryi', 'Christ']
# ['Monachosorum maximowiczii', '(Baker) Hayata']
# ['Paesia radula', '(Baker) C.Chr.']
# ['Pteridium revolutum', '(Blume) Nakai']
# ['Shortia rotundifolia var. ritoensis', '(Hayata) T.C.Huang & A.Hsiao']
# ['Shortia rotundifolia var. rotundifolia', '']
# ['Shortia rotundifolia var. transalpine', '(Hayata) T.Yamaz.']
# ['Cibotium barometz', '(L.) J.Sm.']
# ['Cibotium taiwanense', 'C.M.Kuo']
# ['Cyrtomium fortunei', 'J.Sm.']
# ['Cyrtomium macrophyllum var. macrophyllum', '']
# ['Cyrtomium macrophyllum var. simadae', 'Tagawa']
# ['Cyrtomium nervosum', 'Ching & K.H.Shing']
# ['Cyrtomium caryotideum', '(Wall. ex Hook. & Grev.) C.Presl']
# ['Cyrtomium falcatum subsp. falcatum', '']
# ['Cyrtomium taiwanense', 'Tagawa']
# ['Dryopteris atrata', '(Wall. ex Kunze) Ching']
# ['Dryopteris barbigera', '(T.Moore ex Hook.) Kuntze']
# ['Dryopteris cacaina', 'Tagawa']
# ['Dryopteris championii', '(Benth.) C.Chr. ex Ching']
# ['Dryopteris chrysocoma', '(H.Christ) C.Chr.']
# ['Dryopteris costalisora', 'Tagawa']
# ['Dryopteris cycadina', '(Franch. & Sav.) C.Chr.']
# ['Dryopteris dickinsii', '(Franchet & Savatier) C.Christensen']
# ['Dryopteris diffracta', '(Baker) C.Chr.']
# ['Dryopteris enneaphylla var. enneaphylla', '']
# ['Dryopteris formosana', '(H.Christ) C.Chr.']
# ['Dryopteris fructuosa', '(Christ) C.Chr.']
# ['Dryopteris hasseltii', '(Blume) C.Chr.']
# ['Dryopteris hendersoni', '(Bedd.) C.Chr.']
# ['Dryopteris huangshanensis', 'Ching']
# ['Dryopteris indusiata', '(Makino) Makino & Yamam. ex Yamam.']
# ['Dryopteris integriloba', 'C.Chr.']
# ['Dryopteris komarovii', 'Kosshinsky']
# ['Dryopteris kwanzanensis', 'Tagawa']
# ['Dryopteris labordei', '(H.Christ) C.Chr.']
# ['Dryopteris latibasis', 'Ching']
# ['Dryopteris namegatae', '(Sa.Kurata) Sa.Kurata']
# ['Dryopteris peranema', 'Li Bing Zhang']
# ['Dryopteris polita', 'Rosenst.']
# ['Dryopteris pseudocaenopteris', '(Kunze) Li Bing Zhang']
# ['Dryopteris pseudolunanensis', 'Tagawa']
# ['Dryopteris redactopinnata', 'S.K.Basu & Panigrahi']
# ['Dryopteris ryo-itoana', 'Sa.Kurata']
# ['Dryopteris scottii', '(Bedd.) Ching']
# ['Dryopteris serratodentata', '(Bedd.) Hayata']
# ['Dryopteris sinofibrillosa', 'Ching']
# ['Dryopteris sordidipes', 'Tagawa']
# ['Dryopteris squamiseta', '(Hook.) Kuntze']
# ['Dryopteris stenolepis', '(Baker) C.Chr.']
# ['Dryopteris subatrata', 'Tagawa']
# ['Dryopteris subexaltata', '(Christ) C.Chr.']
# ['Dryopteris subtriangularis', '(C.Hope) C.Chr.']
# ['Dryopteris tenuipes', '(Rosenst.) Seriz.']
# ['Dryopteris toyamae', 'Tagawa']
# ['Dryopteris varia', '(L.) Kuntze']
# ['Dryopteris wallichiana subsp. wallichiana', '']
# ['Dryopteris wuzhaohongii', 'Li Bing Zhang']
# ['Dryopteris × subreflexipinna ', 'Ogata']
# ['Hypericum geminiflorum', 'Hemsl.']
# ['Dryopteris yoroii', 'Seriz.']
# ['Polystichum acanthophyllum', '(Franch.) H.Christ']
# ['Polystichum atkinsonii', 'Bedd.']
# ['Carex atrata', 'L.']
# ['Polystichum hancockii', '(Hance) Diels']
# ['Polystichum attenuatum', 'Tagawa et K.Iwats.']
# ['Polystichum chunii', 'Ching']
# ['Polystichum deltodon', '(Baker) Diels']
# ['Polystichum formosanum', 'Rosenst.']
# ['Polystichum fraxinellum', '(H.Christ) Diels']
# ['Polystichum glaciale', 'Christ']
# ['Polystichum herbaceum', 'Ching & Z.Y.Liu']
# ['Polystichum lachenense', '(Hook.) Bedd.']
# ['Polystichum lepidocaulon', '(Hook.) J.Sm.']
# ['Polystichum luctuosum', '(Kunze) T.Moore']
# ['Polystichum mucronifolium', '(Blume) Nayar & Kaur']
# ['Polystichum neo-lobatum', 'Nakai']
# ['Polystichum nepalense', '(Spreng.) C.Chr.']
# ['Polystichum obliquum', '(D.Don) Moore']
# ['Polystichum parvipinnulum', 'Tagawa']
# ['Polystichum prescottianum', '(Wall. ex Mett.) Moore']
# ['Polystichum prionolepis', 'Hayata']
# ['Polystichum sinense', '(H.Christ) H.Christ']
# ['Polystichum taizhongense', 'H.S.Kung']
# ['Polystichum tenuius', '(Ching) Li Bing Zhang']
# ['Polystichum thomsonii', '(Hook.f.) Bedd.']
# ['Polystichum xiphophyllum', '(Baker) Diels']
# ['Diospyros japonica', 'Siebold & Zucc.']
# ['Diospyros kotoensis', 'T.Yamaz.']
# ['Alsophila acaulis', 'Makino']
# ['Alsophila lepifera', 'J.Sm. ex Hook.']
# ['Alsophila loheri', '(Christ) R.M.Tryon']
# ['Alsophila metteniana', 'Hance']
# ['Alsophila spinulosa', '(Wall. ex Hook.) R.M.Tryon']
# ['Diospyros morrisiana', 'Hance']
# ['Diospyros oldhamii', 'Maxim.']
# ['Diospyros blancoi', 'A. DC.']
# ['Diospyros vaccinioides', 'Lindl.']
# ['Elaeagnus formosana', 'Nakai']
# ['Elaeagnus formosensis', 'Hatus.']
# ['Elaeagnus ohashii', 'T.C.Huang']
# ['Elaeagnus oldhamii', '‘Round’']
# ['Elaeagnus oldhamii', 'Maxim.']
# ['Elaeagnus tarokoensis', 'S.Y.Lu & Yuen P.Yang']
# ['Vaccinium randaiense', 'Hayata']
# ['Elaeagnus thunbergii', 'Serv.']
# ['Elaeagnus umbellata', 'Thunb.']
# ['Elaeocarpus argenteus', 'Merr.']
# ['Elaeocarpus japonicus', 'Siebold & Zucc.']
# ['Sloanea formosana', 'H.L.Li']
# ['Bergia ammannioides', 'Roxb.']
# ['Elatine ambigua', 'Wight']
# ['Equisetum ramosissimum subsp. debile', '(Roxb.) Hauke']
# ['Equisetum ramosissimum subsp. ramosissimum', '']
# ['Gaultheria cumingiana', 'Vidal']
# ['Gaultheria itoana', 'Hayata']
# ['Lyonia ovalifolia var. lanceolata', '(Wall.) Hand.-Mazz.']
# ['Lyonia ovalifolia var. ovalifolia', '']
# ['Pieris taiwanensis', 'Hayata']
# ['Rhododendron chilanshanense', 'Kurashige']
# ['Rhododendron farrerae', 'Sweet']
# ['Rhododendron oldhamii', 'Maxim.']
# ['Rhododendron ovatum var. lamprophyllum', '(Hayata) Y.C.Liu, F.Y.Lu & C.H.Ou']
# ['Rhododendron ovatum var. ovatum', '']
# ['Rhododendron rubropilosum var. taiwanalpinum', '(Ohwi) S.Y.Lu, Yuen P.Yang & Y.H.Tseng']
# ['Vaccinium bracteatum', 'Thunb.']
# ['Vaccinium japonicum var. lasiostemon', 'Hayata']
# ['Vaccinium kengii', 'C.E.Chang']
# ['Vaccinium merrillianum', 'Hayata']
# ['Vaccinium wrightii var. wrightii', '']
# ['Acalypha akoensis', 'Hayata']
# ['Acalypha aristata', 'Kunth']
# ['Acalypha australis', 'L.']
# ['Acalypha caturus', 'Blume']
# ['Acalypha hontauyuensis', 'H.Keng.']
# ['Acalypha indica var. indica', '']
# ['Acalypha longi-acuminata', 'Hayata']
# ['Acalypha matudai', 'Hayata']
# ['Asarum macranthum', 'Hook.f.']
# ['Acalypha suirenbiensis', 'Yamam.']
# ['Alchornea trewioides var. formosae', '(Müll.Arg.) Pax & Hoffm.']
# ['Antidesma hiiranense', 'Hayata']
# ['Antidesma japonicum var. densiflorum', 'Hurus.']
# ['Antidesma pentandrum var. barbatum', '(C.Presl) Merr.']
# ['Antidesma pleuricum', 'Tul.']
# ['Breynia officinalis var. officinalis', '']
# ['Bridelia balansae', 'Tutcher']
# ['Bridelia tomentosa', 'Blume']
# ['Chamaesyce atoto', '(Forst.f.) Croizat']
# ['Chamaesyce garanbiensis', '(Hayata) H.Hara']
# ['Chamaesyce hirta', '(L.) Millsp.']
# ['Chamaesyce hsinchuensis', 'S.C.Lin & S.M.Chaw']
# ['Chamaesyce maculata', '(L.) Small']
# ['Chamaesyce makinoi', '(Hayata) H.Hara']
# ['Chamaesyce prostrata', '(Aiton) Small']
# ['Chamaesyce serpens', '(Kunth) Small']
# ['Chamaesyce tashiroi', '(Hayata) H.Hara']
# ['Chamaesyce thymifolia', '(L.) Millsp.']
# ['Chamaesyce vachellii', '(Hook. & Arn.) Hurus.']
# ['Croton bonplandianus', 'Baillon']
# ['Croton cascarilloides', 'Raeusch.']
# ['Croton tiglium', 'L.']
# ['Drypetes karapinensis', '(Hayata) Pax']
# ['Drypetes littoralis', '(C.B.Rob.) Merr.']
# ['Euphorbia heterophylla', 'L.']
# ['Euphorbia jolkini', 'Boiss.']
# ['Euphorbia peplus', 'L.']
# ['Euphorbia shouanensis', 'H.Keng']
# ['Euphorbia tarokoensis', 'Hayata']
# ['Euphorbia tirucalli', 'L.']
# ['Excoecaria formosana', '(Hayata) Hayata']
# ['Excoecaria kawakamii', 'Hayata']
# ['Flueggea suffruticosa', '(Pall.) Baill.']
# ['Glochidion acuminatum', 'Müll.Arg.']
# ['Glochidion kusukusense', 'Hay.']
# ['Glochidion ovalifolium', 'F.Y.Lu & Y.S.Hsu']
# ['Glochidion philippicum', '(Cavan.) C.B.Rob.']
# ['Glochidion rubrum', 'Blume']
# ['Glochidion zeylanicum var. lanceolatum', '(Hayata) M.J.Deng & J.C.Wang']
# ['Glochidion zeylanicum var. tomentosum', 'Trimem']
# ['Glochidion zeylanicum var. zeylanicum', '']
# ['Liodendron formosanum', '(Kaneh. & Sasaki) H.Keng']
# ['Macaranga sinensis', 'Müll.Arg.']
# ['Macaranga tanarius', '(L.) Müll.Arg.']
# ['Mallotus paniculatus var. formosanus', '(Hayata) Hurus.']
# ['Mallotus paniculatus var. paniculatus', '']
# ['Mallotus philippensis', '(Lam.) Müll.Arg.']
# ['Manihot esculenta', 'Crantz']
# ['Margaritaria indica', '(Daiz.) Airy Shaw']
# ['Melanolepis multiglandulosa', '(Reinw.) Rchb.f. & Zoll.']
# ['Mercurialis leiocarpa', 'Siebold & Zucc.']
# ['Phyllanthus debilis', 'Klen ex Willd.']
# ['Phyllanthus embergeri', 'Haic. & Rossign.']
# ['Phyllanthus hookeri', 'Müll.Arg.']
# ['Phyllanthus multiflorus', 'Willd.']
# ['Ricinus communis', 'L.']
# ['Castanopsis cuspidata var. carlesii', '(Hemsl.) T.Yamaz.']
# ['Castanopsis eyrei', '(Champ. ex Benth.) Hutch.']
# ['Castanopsis fabri', 'Hance']
# ['Castanopsis fargesii', 'Franch.']
# ['Castanopsis formosana', '(Skan) Hayata']
# ['Castanopsis indica', '(Rox.) A.DC.']
# ['Castanopsis kawakamii', 'Hayata']
# ['Castanopsis kusanoi', 'Hayata']
# ['Fagus hayatae', 'Palib.']
# ['Lithocarpus amygdalifolius', '(Skan ex Forbes & Hemsl.) Hayata']
# ['Lithocarpus chiaratuangensis', '(J.C.Liao) J.C.Liao']
# ['Lithocarpus formosanus', '(Skan ex Forbes & Hemsl.) Hayata']
# ['Lithocarpus glaber', '(Thunb.) Nakai']
# ['Lithocarpus hancei', '(Benth.) Rehder']
# ['Lithocarpus kawakamii', '(Hayata) Hayata']
# ['Lithocarpus konishii', '(Hayata) Hayata']
# ['Lithocarpus nantoensis', '(Hayata) Hayata']
# ['Lithocarpus synbalanos', '(Hance) Chun']
# ['Lithocarpus taitoensis', '(Hayata) Hayata']
# ['Quercus acutissima', 'Carruth.']
# ['Quercus aliena', 'Blume']
# ['Quercus championii', 'Benth.']
# ['Quercus dentata', 'Thunb.']
# ['Quercus glauca var. glauca', '']
# ['Quercus glauca var. kuyuensis', 'J.C.Liao']
# ['Quercus hypophaea', 'Hayata']
# ['Quercus morii', 'Hayata']
# ['Quercus myrsinifolia', 'Blume']
# ['Quercus pachyloma', 'Seemen']
# ['Quercus repandifolia', 'J.C.Liao']
# ['Mariscus sumatrensis', '(Retz.) J.Raynal']
# ['Schoenoplectiella juncoides', '(Roxb.) Lye']
# ['Schoenoplectiella mucronata subsp. robusta', '(Miq.) T.C.Hsu']
# ['Schoenoplectiella multiseta', '(Hayasaka & C.Sato) Hayasaka']
# ['Schoenoplectiella wallichii', '(Nees) Lye']
# ['Quercus salicina', 'Blume']
# ['Quercus sessilifolia', 'Blume']
# ['Quercus spinosa', 'David ex Franch.']
# ['Quercus tarokoensis', 'Hayata']
# ['Quercus tatakaensis', 'Tomiya']
# ['Quercus variabilis', 'Blume']
# ['Casearia membranacea', 'Hance']
# ['Homalium cochinchinensis', '(Lour.) Druce']
# ['Idesia polycarpa', 'Maxim.']
# ['Scolopia oldhamii', 'Hance']
# ['Xylosma congesta', '(Lour.) Merr.']
# ['Corydalis incisa', '(Thunb.) Pers.']
# ['Corydalis koidzumiana', 'Ohwi']
# ['Corydalis ochotensis', 'Turcz.']
# ['Corydalis ophiocarpa', 'Hook.f. & Thomsson']
# ['Corydalis pallida var. sparsimamma', '(Ohwi) Ohwi']
# ['Corydalis tashiroi', 'Makino']
# ['Fumaria officinalis', 'L.']
# ['Centaurium pulchellum var. altaicum', '(Griseb.) Kitag. & H.Hara']
# ['Gentiana arisanensis', 'Hayata']
# ['Gentiana davidii var. formosana', '(Hayata) T.N.Ho']
# ['Gentiana flavomaculata var. flavomaculata', '']
# ['Neolitsea buisanensis', 'Yamam. & Kamik.']
# ['Gentiana itzershanensis', 'T.S.Liu & Chiu C.Kuo']
# ['Gentiana kaohsiungensis', 'C.H.Chen & J.C.Wang']
# ['Gentiana scabrida', 'Hayata']
# ['Nymphoides coreana', "(H.L''ev.) H.Hara"]
# ['Erodium cicutarium', "(L.) L''Her."]
# ['Gentiana scabrida var. punctulata', 'S.S.Ying']
# ['Gentiana tatakensis', 'Masam.']
# ['Gentiana tentyoensis', 'Masam.']
# ['Gentiana tenuissima', 'Hayata']
# ['Nymphoides indica', '(L.) Kuntze']
# ['Nymphoides lungtanensis', 'S.P.Li., T.H.Hsieh & C.C.Lin']
# ['Nymphoides peltata', '(S.G.Gmel.) Kuntze']
# ['Pterygocalyx volubilis', 'Maxim.']
# ['Swertia changii', 'S.Z.Yang, C.F.Chen & C.H.Chen']
# ['Swertia macrosperma', '(C.B.Clarke) C.B.Clarke']
# ['Swertia shintenensis', 'Hayata']
# ['Swertia tozanensis', 'Hayata']
# ['Tripterospermum cordifolium', '(Yamam.) Satake']
# ['Tripterospermum hualienense', 'T.C.Hsu & S.W.Chung']
# ['Tripterospermum lanceolatum', '(Hayata) H.Hara ex Satake']
# ['Tripterospermum luzonense', '(Vidal) J.Murata']
# ['Tripterospermum microphyllum', 'Harry Sm.']
# ['Tripterospermum taiwanense', '(Masam.) Satake']
# ['Chirita anachoreta', 'Hance']
# ['Conandron ramondioides', 'Siebold & Zucc.']
# ['Epithema taiwanense var. fasciculatum', '(C.B. Clarke) Z.Yu Li & M.T. Kao']
# ['Epithema taiwanense var. taiwanense', '']
# ['Hemiboea bicornuta', '(Hayata) Ohwi']
# ['Lysionotus pauciflorus var. pauciflorus', '']
# ['Rhynchoglossum obliquum var. hologlossum', '(Hayata) W.T.Wang']
# ['Rhynchotechum discolor', '(Maxim.) B.L.Burtt']
# ['Titanotrichum oldhamii', '(Hemsl.) Soler.']
# ['Dicranopteris linearis', '(Burm.f.) Underw.']
# ['Dicranopteris subpectinata', '(Christ) C.M.Kuo']
# ['Dicranopteris taiwanensis', 'Ching & P.S.Chiu']
# ['Dicranopteris tetraphylla', '(Rosenst.) C.M.Kuo']
# ['Diplopterygium chinensis', '(Rosenst.) DeVol']
# ['Diplopterygium glaucum', '(Thunb. ex Houtt.) Nakai']
# ['Diplopterygium laevissimum', '(H.Christ) Nakai']
# ['Scaevola hainanensis', 'Hance']
# ['Prosaptia contigua', '(G.Forst.) C.Presl']
# ['Prosaptia formosana', '(Hayata) T.C.Hsu']
# ['Prosaptia obliquata', '(Blume) Mett.']
# ['Prosaptia urceolaris', '(Hayata) Copel.']
# ['Radiogrammitis beddomeana', '(Alderw.) Parris']
# ['Radiogrammitis ilanensis', 'T.C.Hsu']
# ['Radiogrammitis setigera', '(Blume) Parris']
# ['Radiogrammitis subnervosa', 'T.C.Hsu']
# ['Radiogrammitis taiwanensis', 'Parris & Ralf Knapp']
# ['Scleroglossum sulcatum', '(Mett. ex Kuhn) Alderw.']
# ['Calophyllum inophyllum', 'L.']
# ['Garcinia linii', 'C.E.Chang']
# ['Garcinia multiflora', 'Champ.']
# ['Hypericum ascyron', 'L.']
# ['Hypericum erectum', 'Thunb.']
# ['Hypericum formosanum', 'Maxim.']
# ['Hypericum gramineum', 'G.Forst.']
# ['Hypericum japonicum', 'Thunb.']
# ['Hypericum nagasawai', 'Hayata']
# ['Hypericum nakamurai', '(Masam.) Robson']
# ['Hypericum patulum', 'Thunb. ex Murray']
# ['Hypericum sampsonii', 'Hance']
# ['Hypericum subalatum', 'Hayata']
# ['Triadenum breviflorum', '(Wall. ex Dyer) Y.Kimura']
# ['Haloragis micrantha', '(Thunb.) R.Br.']
# ['Myriophyllum aquaticum', '(Vell.) Verdc.']
# ['Myriophyllum dicoccum', 'F.Muell.']
# ['Myriophyllum spicatum', 'L.']
# ['Corylopsis pauciflora', 'Siebold & Zucc.']
# ['Corylopsis stenopetala', 'Hayata']
# ['Distyliopsis dunnii', '(Hemsl.) Endress']
# ['Distylium gracile', 'Nakai']
# ['Crepidomanes grande', '(Copel.) Ebihara & K.Iwats.']
# ['Crepidomanes humile', '(G.Forst.) Bosch']
# ['Crepidomanes kurzii', '(Bedd.) Tagawa & K.Iwats.']
# ['Crepidomanes latealatum', '(Bosch) Copel.']
# ['Crepidomanes makinoi', '(C.Chr.) Copel.']
# ['Crepidomanes minutum', '(Blume) K.Iwats.']
# ['Crepidomanes palmifolium', '(Hayata) DeVol']
# ['Crepidomanes parvifolium', '(Baker) K.Iwats.']
# ['Crepidomanes schmidtianum var. latifrons', '(Bosch) K.Iwats.']
# ['Crepidomanes vitiense', '(Baker) Bostock']
# ['Hymenophyllum paniculiflorum', 'C.Presl']
# ['Hymenophyllum pilosissimum', 'C.Chr.']
# ['Hymenophyllum polyanthos', '(Sw.) Sw.']
# ['Hymenophyllum productum', 'Kunze']
# ['Hymenophyllum simonsianum', 'Hook.']
# ['Vandenboschia auriculata', '(Blume) Copel.']
# ['Vandenboschia kalamocarpa', '(Hayata) Ebihara']
# ['Vandenboschia maxima', '(Blume) Copel.']
# ['Illicium anisatum', 'L.']
# ['Illicium arborescens', 'Hayata']
# ['Illicium tashiroi', 'Maxim.']
# ['Engelhardia roxburghiana', 'Wall.']
# ['Juglans cathayensis', 'Dode']
# ['Platycarya strobilacea', 'Siebold & Zucc.']
# ['Clinopodium gracile', '(Benth.) Kuntze']
# ['Clinopodium laxiflorum var. taiwanianum', 'T.H.Hsieh & T.C.Huang']
# ['Coleus amboinicus', 'Lour.']
# ['Elsholtzia ciliata', '(Thunb.) Hylander']
# ['Elsholtzia strobilifera', 'Benth.']
# ['Glechoma hederacea var. grandis', '(A.Gray) Kudo']
# ['Gomphostemma callicarpoides', '(Yamam.) Masam.']
# ['Hyptis brevipes', 'Poir.']
# ['Hyptis rhomboides', 'Mart. & Gal.']
# ['Hyptis spicigera', 'Lam.']
# ['Hyptis suaveolens', '(L.) Poir.']
# ['Isodon amethystoides', '(Benth.) H.Hara']
# ['Isodon serra', '(Maxim.) Kudo']
# ['Lamium amplexicaule', 'L.']
# ['Lamium hybridum', 'Vill.']
# ['Lamium purpureum', 'L.']
# ['Lamium tuberiferum', '(Makino) Ohwi']
# ['Leonurus japonicus', 'Houtt.']
# ['Lycopus lucidus', 'Turcz.']
# ['Melissa axillaris', 'Bakh.f.']
# ['Mentha arvensis subsp. piperascens', '(Malinv. ex Holmes) H.Hara']
# ['Mosla chinensis', 'Maxim.']
# ['Mosla scabra', '(Thunb.) C.Y.Wu & H.W.Li']
# ['Origanum vulgare', 'L.']
# ['Orthosiphon aristatus', '(Blume) Miq.']
# ['Paraphlomis javanica', '(Blume) Prain']
# ['Perilla frutescens', '(L.) Britt.']
# ['Rubiteucris palmata', '(Benth. ex Hook.f.) Kudo']
# ['Salvia arisanensis', 'Hayata']
# ['Salvia coccinea', 'Juss. ex Murray']
# ['Salvia formosana var. matsudae', '(Kudo) T.C.Huang & J.T.Wu']
# ['Salvia hayatana', 'Makino ex Hayata']
# ['Salvia japonica', 'Thunb.']
# ['Salvia keitaoensis', 'Hayata']
# ['Salvia lyrata', 'L.']
# ['Salvia occidentalis', 'Sw.']
# ['Salvia plebeia', 'R.Br.']
# ['Salvia scapiformis', 'Hance']
# ['Salvia tashiroi', 'Hayata']
# ['Scutellaria barbata', 'D.Don']
# ['Scutellaria hsiehii', 'T.H.Hsieh']
# ['Scutellaria indica', 'L.']
# ['Scutellaria playfairii', 'Kudo']
# ['Scutellaria taipeiensis', 'T.C.Huang, A.Hsiao et M.J.Wu']
# ['Scutellaria taiwanensis', 'C.Y.Wu']
# ['Scutellaria tashiroi', 'Hayata']
# ['Suzukia luchuensis', 'Kudo']
# ['Suzukia shikikunensis', 'Kudo']
# ['Teucrium bidentatum', 'Hemsl.']
# ['Teucrium viscidum', 'Blume']
# ['Akebia longeracemosa', 'Matsum.']
# ['Akebia trifoliata subsp. australis', '(Diels) T.Shimizu']
# ['Stauntonia hexaphylla', '(Thunb.) Dcene.']
# ['Stauntonia obovata', 'Hemsl.']
# ['Beilschmiedia erythrophloia', 'Hayata']
# ['Beilschmiedia tsangii', 'Merr.']
# ['Cassytha filiformis', 'L.']
# ['Cinnamomum austrosinense', 'H.T.Chang']
# ['Cinnamomum brevipedunculatum', 'C.E.Chang']
# ['Cinnamomum camphora var. camphora', '']
# ['Cinnamomum camphora var. nominale', 'Hayata ex Matsum. & Hayata']
# ['Cinnamomum insulari-montanum', 'Hayata']
# ['Cinnamomum kanehirae', 'Hayata']
# ['Cinnamomum osmophloeum', 'Kaneh.']
# ['Cinnamomum reticulatum', 'Hayata']
# ['Ajuga pygmaea', 'A.Gray']
# ['Cryptocarya chinensis', '(Hance) Hemsl.']
# ['Cryptocarya concinna', 'Hance']
# ['Dehaasia incrassata', '(Jack.) Kosterm.']
# ['Endiandra coriacea', 'Merr.']
# ['Lindera aggregata', '(Sims) Kosterm.']
# ['Lindera aggregata', '(Sims) Kosterm. f. playfairii (Hemsl.) J.C.Liao']
# ['Lindera akoensis', 'Hayata']
# ['Lindera communis', 'Hemsl.']
# ['Lindera erythrocarpa', 'Makino']
# ['Lindera megaphylla', 'Hemsl.']
# ['Lindera thunbergii', '(Sieb. & Zucc.) Makino']
# ['Litsea acuminata', '(Blume) Kurata']
# ['Litsea acutivena', 'Hayata']
# ['Litsea akoensis var. chitouchiaoensis', 'J.C.Liao']
# ['Litsea akoensis var. sasakii', '(Kamik.) J.C.Liao']
# ['Litsea coreana', 'H.Lév.']
# ['Litsea cubeba', '(Lour.) Per.']
# ['Litsea garciae', 'Vidal']
# ['Litsea hypophaea', 'Hayata']
# ['Litsea lii var. lii', '']
# ['Litsea lii var. nunkao-tahangensis', '(J.C.Liao) J.C.Liao']
# ['Litsea linii', 'Chang']
# ['Litsea morrisonensis', 'Hayata']
# ['Litsea rotundifolia var. oblongifolia', '(Nees) Allen']
# ['Machilus japonica var. japonica', '']
# ['Machilus japonica var. kusanoi', '(Hayata) J.C.Liao']
# ['Machilus konishii', 'Hayata']
# ['Machilus obovatifolia var. taiwuensis', 'S.Y.Lu & T.T.Chen']
# ['Machilus philippinensis', 'Merr.']
# ['Machilus thunbergii', 'Siebold & Zucc.']
# ['Machilus zuihoensis var. zuihoensis', '']
# ['Neolitsea aciculata var. aciculata', '']
# ['Neolitsea aciculata var. variabillima', '(Hayata) J.C.Liao']
# ['Neolitsea acuminatissima', '(Hayata) Kaneh. & Sasaki']
# ['Neolitsea konishii', '(Hayata) Kaneh. & Sasaki']
# ['Mentha canadensis', 'L.']
# ['Neolitsea sericea var. aurata', '(Hayata) Hatus.']
# ['Neolitsea sericea var. sericea', '']
# ['Neolitsea villosa', '(Blume) Merr.']
# ['Phoebe formosana', '(Hayata) Hayata']
# ['Sassafras randaiense', '(Hayata) Rehder']
# ['Barringtonia racemosa', '(L.) Blume ex DC.']
# ['Leea philippinensis', 'Merr.']
# ['Abrus precatorius', 'L.']
# ['Acacia caesia', '(L.) Willd']
# ['Acacia confusa', 'Merr.']
# ['Aeschynomene americana var. americana', '']
# ['Aeschynomene americana var. glandulosa', '(Poir.) Rudd.']
# ['Aeschynomene indica', 'L.']
# ['Albizia julibrissin', 'Durazz.']
# ['Albizia lebbeck', '(L.) Benth.']
# ['Albizia procera', '(Roxb.) Benth.']
# ['Gelonium aequoreum', 'Hance']
# ['Albizia retusa', 'Benth.']
# ['Alysicarpus ovalifolius', '(Schum.) J.Léonard']
# ['Alysicarpus rugosus', '(Willd.) DC.']
# ['Alysicarpus vaginalis var. taiwanensis', 'S.S.Ying']
# ['Alysicarpus vaginalis var. vaginalis', '']
# ['Apios taiwanianus', 'Hosok.']
# ['Archidendron lucidum', '(Benth.) I.Nielsen']
# ['Astragalus nankotaizanensis', 'Sasaki']
# ['Astragalus nokoensis', 'Sasaki']
# ['Astragalus sinicus', 'L.']
# ['Bauhinia purpurea', 'L.']
# ['Bauhinia variegata', 'L.']
# ['Caesalpinia bonduc', '(L.) Roxb.']
# ['Caesalpinia crista', 'L.']
# ['Caesalpinia minax', 'Hance']
# ['Cajanus scarabaeoides', '(L.) Thouars']
# ['Callerya nitida', '(Benth.) R.Geesink']
# ['Canavalia rosea', '(Sw.) DC.']
# ['Stachys arvensis', 'L.']
# ['Cassia sophora var. penghuana', 'Y.C.Liu ＆ F.Y.Lu']
# ['Centrosema pubescens', 'Benth.']
# ['Hypericum nokoense', 'Ohwi']
# ['Chamaecrista mimosoides', '(L.) Greene']
# ['Chamaecrista nomame', '(Siebold) H.Ohashi']
# ['Christia campanulata', '(Benth.) Thoth.']
# ['Christia obcordata', '(Poir.) Bakh.f. ex Meeuwen']
# ['Clitoria falcata', 'Lam.']
# ['Clitoria ternatea', 'L.']
# ...
# ['Staurogyne concinnula', '(Hance) Kuntze']
# ['Staurogyne debilis', '(T.Anderson) C.B.Clarke ex Mill.']
# ['Strobilanthes cusia', '(Ness) Kuntze']
# ['Strobilanthes flexicaulis', 'Hayata']
# ['Strobilanthes lanyuensis', 'Seok, C.F.Hsieh & J.Murata']
# ['Strobilanthes longespicatus', 'Hayata']
# ['Strobilanthes penstemonoides', 'T.Anderson']
# ['Strobilanthes wallichii', 'Nees']
# ['Thunbergia alata', 'Bojer ex Sims']
# ['Thunbergia fragrans', 'Roxb.']
# ['Thunbergia grandiflora', 'Roxb.']
# ['Acer albopurpurascens', 'Hayata']
# ['Acer kawakamii', 'Koidz.']
# ['Trianthema portulacastrum', 'L.']
# ['Alangium chinense', '(Lour.) Rehder']
# ['Achyranthes aspera var. indica', 'L.']
# ['Achyranthes aspera var. rubro-fusca', 'Hook.f.']
# ['Semecarpus cuneiformis', 'Blanco']
# ['Ilex tugitakayamensis', 'Sasaki']
# ['Ilex yunnanensis var. parvifolia', '(Hayata) S.Y.Hu']
# ['Aralia armata', '(Wall.) Seem.']
# ['Tectaria zeylanica', '(Houtt.) Sledge']
# ['Spathodea campanulata', 'Beauv.']
# ['Brainea insignis', '(Hook.) J.Sm.']
# ['Diploblechnum fraseri', '(A.Cunn.) DeVol']
# ['Struthiopteris hancockii', '(Hance) Tagawa']
# ['Woodwardia harlandii', 'Hook.']
# ['Buxus liukiuensis', '‘Round’']
# ['Carica papaya', 'L.']
# ['Chenopodium ambrosioides', 'L.']
# ['Chenopodium formosanum', 'Koidz.']
# ['Chenopodium glaucum', 'L.']
# ['Suaeda maritima', '(L.) Dum.']
# ['Chloranthus henryi', 'Hemsl.']
# ['Chloranthus oldhami', 'Solms.']
# ['Sarcandra glabra', '(Thunb.) Nakai']
# ['Terminalia catappa', 'L.']
# ['Acmella brachyglossa', 'Cass.']
# ['Acmella ciliata', '(Kunth) Cass.']
# ['Acmella paniculata', '(Wall. ex DC.) R.K.Jansen']
# ['Ageratina adenophora', '(Spreng.) R.M.King & H.Rob.']
# ['Ageratina riparia', '(Regel) R.M.King & H.Rob.']
# ['Ageratum conyzoides', 'L.']
# ['Ageratum houstonianum', 'Mill.']
# ['Ainsliaea fragrans', 'Champ.']
# ['Blumea formosana', 'Kitam.']
# ['Petasites formosanus', 'Kitam.']
# ['Tridax procumbens', 'L.']
# ['Sedum drymarioides', 'Hance']
# ['Sisymbrium orientale', 'L.']
# ['Thlaspi arvense', 'L.']
# ['Actinostemma tenerum', 'Griff.']
# ['Coccinia grandis', '(L.) Voigt']
# ['Gymnopetalum chinense', '(Lour.) Merr.']
# ['Gynostemma pentaphyllum', '(Thunb.) Makino']
# ['Melothria pendula', 'L.']
# ['Momordica charantia', 'L.']
# ['Mukia maderaspatana', '(L.) M.J.Roem.']
# ['Daphniphyllum glaucescens subsp. oldhamii var. kengii', '(Hurus.) T.C.Huang']
# ['Daphniphyllum glaucescens subsp. oldhamii var. lanyuense', 'T.C.Huang']
# ['Davallia chrysanthemifolia', 'Hayata']
# ['Davallia divaricata', 'Blume']
# ['Davallia griffithiana', 'Hook.']
# ['Davallia pectinata', 'Sm.']
# ['Davallia perdurans', 'H.Christ']
# ['Davallia repens', '(L.f.) Kuhn']
# ['Davallia solida', '(G.Forst.) Sw.']
# ['Dipteris conjugata', 'Reinw.']
# ['Drosera burmannii', 'Vahl']
# ['Drosera indica', 'L.']
# ['Drosera spathulata', 'Lab.']
# ['Arachniodes chinensis', '(Rosenst.) Ching']
# ['Arachniodes festina', '(Hance) Ching']
# ['Arachniodes globisora', '(Hayata) Ching']
# ['Arachniodes nigrospinosa', '(Ching) Ching']
# ['Arachniodes pseudoaristata', '(Tagawa) Ohwi']
# ['Arachniodes rhomboidea var. rhomboidea', '']
# ['Cyrtomium falcatum subsp. australe', 'S.Matsumoto ex S.Matsumoto & Ebihara']
# ['Diospyros maritima', 'Blume']
# ['Rhododendron formosanum', 'Hemsl.']
# ['Rhododendron hyperythrum', 'Hayata']
# ['Rhododendron kawakamii', 'Hayata']
# ['Rhododendron lasiostylum', 'Hayata']
# ['Rhododendron leptosanthum', 'Hayata']
# ['Rhododendron mariesii', 'Hemsl. & E.H.Wils.']
# ['Rhododendron simsii', 'Planch.']
# ['Bischofia javanica', 'Blume']
# ['Lithocarpus corneus', '(Lour.) Rehder']
# ['Quercus gilva', 'Blume']
# ['Corydalis racemosa', '(Thunb.) Pers.']
# ['Geranium hayatanum', 'Ohwi']
# ['Geranium molle', 'L.']
# ['Geranium pusillum', 'L.']
# ['Geranium robertianum', 'L.']
# ['Geranium suzukii', 'Masam.']
# ['Geranium wilfordii', 'Maxim.']
# ['Aeschynanthus acuminatus', 'Wall. ex A.DC.']
# ['Erodium moschatum', "(L.) L''Her."]
# ['Galium fukuyamai', 'Masam.']
# ['Ocimum basilicum', 'L.']
# ['Milium effusum', 'L.']
# ['Calymmodon gracilis', '(Fée) Copel.']
# ['Calymmodon ordinatus', 'Copel.']
# ['Prosaptia pectinata', 'T.Moore']
# ['Eustigma oblongifolium', 'Gardn. & Champ.']
# ['Liquidambar formosana', 'Hance']
# ['Sycopsis sinensis', 'Oliv.']
# ['Hymenophyllum badium', 'Hook. & Grev.']
# ['Illigera luzonensis', '(C.Presl) Merr.']
# ['Hydrolea zeylanica', '(L.) Vahl']
# ['Abrodictyum clathratum', '(Tagawa) Ebihara & K.Iwats.']
# ['Callistopteris apiifolia', '(C.Presl.) Copel.']
# ['Cephalomanes javanicum var. asplenioides', '(C.Presl) K.Iwats.']
# ['Cephalomanes thysanostomum', '(Makino) Ebihara & K.Iwats.']
# ['Crepidomanes bipunctatum', '(Poir.) Copel.']
# ['Hymenophyllum barbatum', '(Bosch) Baker']
# ['Hymenophyllum blandum', 'Racib.']
# ['Hymenophyllum denticulatum', 'Sw.']
# ['Hymenophyllum devolii', 'M.J.Lai']
# ['Hymenophyllum fimbriatum', 'J.Sm.']
# ['Hymenophyllum holochilum', '(Bosch) C.Chr.']
# ['Hymenophyllum javanicum', 'Spreng.']
# ['Hymenophyllum nitidulum', '(Bosch) Ebihara & K.Iwats.']
# ['Hymenophyllum okadae', 'Masam.']
# ['Agastache rugosa', '(Fisch. & Mey.) Kuntze']
# ['Ajuga decumbens', 'Thunb.']
# ['Ajuga taiwanensis', 'Nakai ex Murata']
# ['Anisomeles indica', '(L.) Kuntze']
# ['Bostrychanthera deflexa', 'Benth.']
# ['Clinopodium chinense', '(Benth.) Kuntze']
# ['Coleus formosanus', 'Hayata']
# ['Trifolium pratense', 'L.']
# ['Trigonella hamosa', 'Forssk.']
# ['Uraria aequilobata', 'Hosok.']
# ['Uraria crinita', '(L.) Desv. ex DC.']
# ['Uraria lagopodioides', '(L.) Desv. ex DC.']
# ['Uraria neglecta', 'Prain']
# ['Vicia sativa subsp. nigra', '(L.) Ehrh.']
# ['Vicia tetrasperma', '(L.) Moench']
# ['Vigna adenantha', '(G.F.Meyer) Maréchal']
# ['Vigna luteola', '(Jacq.) Benth.']
# ['Vigna marina', '(Burm.) Merr.']
# ['Urena lobata', 'L.']
# ['Lindsaea chienii', 'Ching']
# ['Lindsaea cultrata', '(Willd.) Sw.']
# ['Lindsaea ensifolia', 'Sw.']
# ['Taxillus rhododendricolius', '(Hayata) S.T.Chiu']
# ['Ficus religiosa', 'L.']
# ['Ficus sarmentosa var. henryi', '(King ex D.Oliver) Corner']
# ['Ficus superba var. japonica', 'Miq.']
# ['Ficus tannoensis', 'Hayata']
# ['Embelia lenticellata', 'Hayata']
# ['Maesa japonica', '(Thunb.) Moritzi ex Zoll.']
# ['Myrsine africana', 'L.']
# ['Myrsine sequinii', 'H.Lév.']
# ['Myrsine stolonifera', '(Koidz.) Walker']
# ['Decaspermum gracilentum', '(Hance) Merr. & L.M.Perry']
# ['Fraxinus insularis', 'Hemsl.']
# ['Oenothera tetraptera', 'Cav.']
# ['Botrychium lanuginosum', 'Wall. ex Hook. & Grev']
# ['Botrychium lunaria', '(L.) Sw.']
# ['Ophioderma pendula', '(L.) C.Presl']
# ['Ophioglossum austroasiaticum', 'M.Nishida']
# ['Ophioglossum parvum', 'M.Nishida & Kurita']
# ['Ophioglossum petiolatum', 'Hook.']
# ['Ophioglossum reticulatum', 'L.']
# ['Ophioglossum thermale', 'Kom.']
# ['Champereia manillana', '(Blume) Merr.']
# ['Eria amica', 'Rchb.f.']
# ['Galium taiwanense', 'Masam.']
# ['Argemone mexicana', 'L.']
# ['Osmunda japonica', 'Thunb.']
# ['Aeginetia indica', 'L.']
# ['Boschniakia himalaica', 'Hook.f. & Thomson']
# ['Christisonia hookeri', 'C.B.Clarke']
# ['Phacellanthus tubiflorus', 'Siebold & Zucc']
# ['Biophytum sensitivum', 'DC.']
# ['Oxalis acetosella subsp. taemoni', '(Yamam.) S.F.Huang & T.C.Huang']
# ['Oxalis corniculata', 'L.']
# ['Oxalis corymbosa', 'DC.']
# ['Macleaya cordata', '(Willd.) R.Br.']
# ['Papaver rhoeas', 'L.']
# ['Ceratopteris thalictroides subsp. thalictroides', '']
# ['Passiflora edulis', 'Sims']
# ['Passiflora suberosa', 'L.']
# ['Phryma leptostachya', 'L.']
# ['Schellolepis persicifolia', '(Desv.) Pic.Serm.']
# ['Portulaca oleracea', 'L.']
# ['Portulaca pilosa subsp. grandiflora', '(Hook.) Geesink']
# ['Portulaca psammotropha', 'Hance']
# ['Portulaca quadrifida', 'L.']
# ['Talinum paniculatum', '(Jacq.) Gaertn.']
# ['Anagallis arvensis', 'L.']
# ['Anagallis minima', '(L.) E.H.L.Krause']
# ['Lysimachia ardisioides', 'Masam.']
# ['Psychotria manillensis', 'Bartl. ex DC.']
# ['Mazus pumilus', '(Burm.f.) Steenis']
# ['Selaginella helvetica subsp. pseudonipponica', '(Tagawa) H.M.Chang, W.L.Chiou & J.C.Wang']
# ['Selaginella heterostachys', 'Baker']
# ['Selaginella involvens', '(Sw.) Spring']
# ['Selaginella leptophylla', 'Baker']
# ['Selaginella lutchuensis', 'Koidz.']
# ['Selaginella moellendorffii', 'Hieron.']
# ['Selaginella nipponica', 'Franch. & Sav.']
# ['Selaginella remotifolia', 'Spring']
# ['Selaginella stauntoniana', 'Spring']
# ['Selaginella tama-montana', 'Seriz.']
# ['Selaginella tamariscina', '(P.Beauv.) Spring']
# ['Selaginella uncinata', '(Desv. ex Poir.) Spring']
# ['Brucea javanica', '(L.) Merr.']
# ['Picrasma quassioides', 'Benn.']
# ['Cyphomandra betacea', '(Cav.) Stendt.']
# ['Datura innoxia', 'Mill.']
# ['Datura metel', 'L.']
# ['Nicandra physalodes', '(L.) Gaertn.']
# ['Styrax formosana var. formosana', '']
# ['Berrya ammonilla', 'Roxb.']
# ['Corchorus aestuans var. aestuans', '']
# ['Corchorus capsularis', 'L.']
# ['Antrophyum castaneum', 'H.Ito']
# ['Antrophyum formosanum', 'Hieron.']
# ['Antrophyum henryi', 'Hieron.']
# ['Antrophyum obovatum', 'Baker']
# ['Antrophyum sessilifolium', '(Cav.) Spreng.']
# ['Vaginularia junghuhnii', 'Mett.']
# ['Vaginularia trichoidea', 'Fée']
# ['Vitex negundo', 'L.']
# ['Hygrophila corymbosa', '(Blume) Lindau']
# ['Hygrophila salicifolia', '(Vahl) Nees']
# ['Justicia procumbens var. hayatae', '(Yamam.) Ohwi']
# ['Lepidagathis formosensis', 'C.B.Clarke ex Hayata']
# ['Peristrophe japonica', '(Thunb.) Bremek.']
# ['Rungia taiwanensis', 'T.Yamaz.']
# ['Strobilanthes formosana', 'S.Moore']
# ['Strobilanthes rankanensis', 'Hayata']
# ['Acer buergerianum var. formosanum', '(Hayata) Sasaki']
# ['Acer palmatum var. pubescens', 'H.L.Li']
# ['Actinidia arguta', '(Sieb. & Zucc.) Planch. ex Miq.']
# ['Actinidia rufa', '(Siebold & Zucc.) Planch. ex Miq.']
# ['Adiantum diaphanum', 'Blume']
# ['Adiantum meishanianum', 'F.S.Hsu ex Yea C.Liu & W.L.Chiou']
# ['Coniogramme fraxinea', '(D.Don) Diels']
# ['Tetragonia tetragonoides', '(Pall.) Kuntze']
# ['Achyranthes longifolia', '(Makino) Makino']
# ['Alternanthera philoxeroides', '(Mart.) Griseb.']
# ['Tribulus terrestris', 'L.']
# ['Tamarix aphylla', '(L.) H.Karst.']
# ['Ilex cochinchinensis', '(Lour.) Loes.']
# ['Ilex lonicerifolia var. lonicerifolia', '']
# ['Ilex rarasanensis', 'Sasaki']
# ['Ilex uraiensis', 'Mori & Yamam.']
# ['Asystasia gangetica subsp. gangetica', '']
# ['Asystasia gangetica subsp. micrantha', '(Nees) Ensermu']
# ['Asystasiella neesiana', '(Wall.) Lindau']
# ['Blechum pyramidatum', '(Lam.) Urb.']
# ['Aralia cordata', 'Thunb.']
# ['Dryopteris apiciflora', '(Wall. ex Mett.) O.Kuntze']
# ['Pleocnemia rufinervis', '(Hayata) Nakai']
# ['Tectaria decurrens', '(C.Presl) Copel.']
# ['Hygrophila difformis', '(L.f.) Blume']
# ['Acer serrulatum', 'Hayata']
# ['Actinidia callosa var. callosa', '']
# ['Fatsia polycarpa', 'Hayata']
# ['Dryopteris melanocarpa', 'Hayata']
# ['Diospyros eriantha', 'Champ. ex Benth.']
# ['Elaeocarpus sylvestris var. sylvestris', '']
# ['Acalypha angatensis', 'Blanco']
# ['Euphorbia formosana', 'Hayata']
# ['Phyllanthus ussuriensis', 'Rupr. & Maxim.']
# ['Phyllanthus virgatus', 'Forst.f.']
# ['Quercus longinux var. longinux', '']
# ['Pinus massoniana', 'Lamb.']
# ['Plagiogyria euphlebia', '(Kunze) Mett.']
# ['Persicaria hydropiper', '(L.) Delarbre']
# ['Persicaria lanata', '(Roxb.) Tzvelev']
# ['Lepisorus obscurevenulosus', '(Hayata) Ching']
# ['Cordia aspera subsp. kanehirai', '(Hayata) H.Y.Liu']
# ['Ehretia longiflora', 'Champ. ex Benth.']
# ['Cheiropleuria integrifolia', '(D.C.Eaton ex Hook.) M.Kato, Y.Yatabe, Sahashi & N.Murak.']
# ['Chenopodium serotinum', 'L.']
# ['Lumnitzera racemosa', 'Willd.']
# ['Acmella oleracea', '(L.) R.K.Jansen']
# ['Ipomoea trifida', '(Kunth) G.Don']
# ['Jacquemontia polyantha', '(Schltdl. & Cham.) Hallier f.']
# ['Merremia hederacea', '(Burm.f.) Hallier f.']
# ['Stictocardia tiliifolia', '(Desr.) Hallier f.']
# ['Benthamidia japonica var. chinensis', '(Osborn) H.Hara']
# ['Bryophyllum pinnatum', '(Lam.) Kurz']
# ['Kalanchoe garambiensis', 'Kudo']
# ['Kalanchoe spathulata', '(Poir.) DC.']
# ['Sedum erythrospermum', 'Hayata']
# ['Sedum parvisepalum', 'Yamam.']
# ['Cardamine agyokumontana', 'Hayata']
# ['Neslia paniculata', '(L.) Desv.']
# ['Mucuna membranacea', 'Hayata']
# ['Daphniphyllum glaucescens subsp. oldhamii', '(Hemsl.) T.C.Huang']
# ['Daphniphyllum himalaense subsp. macropodum', '(Miq.) T.C.Huang']
# ['Davallia vestita', 'Blume']
# ['Dennstaedtia zeylanica', '(Sw.) Zink ex Fraser-Jenk. & Kandel']
# ['Hypolepis tenuifolia', '(G.Forst.) Bernh.']
# ['Microlepia marginata', '(Panzer) C.Chr.']
# ['Microlepia platyphylla', '(D.Don) J.Sm.']
# ['Microlepia substrigosa', 'Tagawa']
# ['Microlepia trichocarpa', 'Hayata']
# ['Pteridium latiusculum subsp. japonicum', '(Nakai) Fraser-Jenk.']
# ['Elaeagnus grandifolia', 'Hayata']
# ['Elaeagnus triflora', 'Roxb.']
# ['Garcinia subelliptica', 'Merr.']
# ['Calymmodon oligotrichus', 'T.C.Hsu']
# ['Grammitis intromissa', '(H.Christ) Parris']
# ['Prosaptia nutans', '(Blume) Mett.']
# ['Radiogrammitis moorei', 'Parris & Ralf Knapp']
# ['Hypericum geminiflorum var. simplicistylum', '(Hayata) N.Robson']
# ['Hypericum taihezanense', 'Sasaki ex S.Suzuki']
# ['Myriophyllum ussuriense', '(Regel) Maxim.']
# ['Distylium racemosum', 'Siebold & Zucc.']
# ['Hernandia nymphiifolia', '(C.Presl) Kubitzki']
# ['Abrodictyum obscurum', '(Blume) Ebihara & K.Iwats.']
# ['Pogostemon formosanus', 'Oliv.']
# ['Crotalaria elliptica', 'Roxb.']
# ['Tadehagi triquetrum subsp. pseudotriquetrum', '(DC.) H.Ohashi']
# ['Trifolium repens', 'L.']
# ['Uraria picta', '(Jacq.) DC.']
# ['Vicia cracca', 'L.']
# ['Vicia hirsuta', '(L.) S.F.Gray']
# ['Vigna angularis var. nipponensis', '(Ohwi) Ohwi & H.Ohashi']
# ['Vigna umbellata', '(Thunb.) Ohwi & H.Ohashi']
# ['Utricularia australis', 'R.Br.']
# ['Utricularia uliginosa', 'Vahl']
# ['Solanum erianthum', 'D.Don']
# ['Lindsaea kawabatae', 'Sa.Kurata']
# ['Lindsaea orbiculata var. commixta', '(Tagawa) W.C.Shieh']
# ['Lycopodium complanatum', 'L.']
# ['Ficus sarmentosa var. nipponica', '(Franch. & Sav.) Corner']
# ['Ficus tannoensis fo. rhombifolia', 'Hayata']
# ['Maclura cochinchinensis', '(Lour.) Corner']
# ['Myristica elliptica var. simiarum', '(A.DC.) J.Sinclair']
# ['Ardisia cornudentata subsp. morrisonensis var. stenosepala', '(Hayata) Yuen P.Yang']
# ['Panicum repens', 'L.']
# ['Corchorus olitorius', 'L.']
# ['Orobanche coerulescens', 'Stephan']
# ['Oxalis acetocella subsp. griffinthii var. formosana', 'S.F.Huang & T.C.Huang']
# ['Ceratopteris thalictroides subsp. gaudichaudii', '(Brongn.) Fraser-Jenk. & Pariyar']
# ['Passiflora foetida var. hispida', '(DC. ex Triana & Planch.) Killip']
# ['Keteleeria davidiana var. formosana', 'Hayata']
# ['Pseudotsuga wilsoniana', 'Hayata']
# ['Peperomia reflexa', '(L.f.) A.Dietr.']
# ['Piper interruptum var. multinervum', 'C.DC.']
# ['Pittosporum daphniphylloides', 'Hayata']
# ['Pittosporum pentandrum', '(Blanco) Merr.']
# ['Pittosporum tobira', 'W.T.Aiton']
# ['Plagiogyria adnata', '(Blume) Bedd.']
# ['Plagiogyria koidzumii', 'Tagawa']
# ['Persicaria capitata', '(Buch.-Ham. ex D.Don) H.Gross']
# ['Veronicastrum axillare var. simadai', '(Masam.) H.Y.Liu']
# ['Selaginella ciliaris', '(Retz.) Spring']
# ['Selaginella doederleinii subsp. Doederleinii', '']
# ['Selaginella labordei', 'Hieron. ex H.Christ']
# ['Selaginella repanda', '(Desv. ex Poir) Spring']
# ['Physalis peruviana', 'L.']
# ['Cyclosorus dentatus', '(Forssk.) Ching*']
# ['Elatostema multicanaliculatum', 'B.L.Shih & Yuen P.Yang']
# ['Elatostema subcoriaceum', 'B.L.Shih & Yuen P.Yang']
# ['Gonostegia pentandra', '(Roxb.) Miq.']
# ['Maoutia setosa', 'Wedd.']
# ['Pellionia radicans', '(Siebold & Zucc.) Wedd.']
# ['Pilea swinglei', 'Merr.']
# ['Agrostis clavata', 'Trin.']
# ['Smilax china', 'L.']
# ['Carex longistipes', 'Hayata']
# ['Ischaemum timorense', 'Kunth']
# ['Liparis rubrotincta', 'T.C.Hsu']
# ['Zeuxine strateumatica var. rupicola', '(Fukuy.) S.S.Ying']
# ['Pinanga tashiroi', 'Hayata']
# ['Pandanus odoratissimus', 'L.f.']
# ['Potamogeton cristatus', 'Regel & Maack']
# ['Smilax bracteata var. verruculosa', '(Merr.) T.Koyama']
# ['Smilax horridiramula', 'Hayata']
# ['Smilax nantoensis', 'T.Koyama']
# ['Smilax planipedunculata var. raishaensis', '(Hayata) T.C.Hsu & S.W.Chung']
# ['Smilax vaginata', 'Decne.']
# ['Stemona tuberosa', 'Lour.']
# ['Sciaphila secundiflora', 'Thwaites ex Benth.']
# ['Xyris formosana', 'Hayata']
# ['Alpinia ilanensis', 'S.C.Liu & J.C.Wang']
# ['Alpinia pricei var. pricei', '']
# ['Alpinia shimadae var. kawakamii', '(Hayata) Jeng J.Yang & J.C.Wang']
# ['Costus speciosus', '(Koenig) Sm.']
# ['Zingiber officinale', 'Roscoe']

# %%
# Out:
# ("Erodium moschatum (L.) L' Her.",)
